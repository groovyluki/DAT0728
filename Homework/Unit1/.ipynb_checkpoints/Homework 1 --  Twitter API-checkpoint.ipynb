# %% [markdown]
# ## Homework 1: Advanced Track -- Harvest the Twitter API

# %% [markdown]
# **Objective:** Write a series of functions that allow you to dynamically harvest Twitter data.
#
# **Estimated Time to Complete:** 4-12 hours
#
# #### Sections
#
#  - **Section 1:** Setting up your developer account, using OAuth1 authentication (approx 45-120 minutes)
#  - **Sections 2 & 3:** Navigating the API documentation, getting your first query strings (approx 45-120 minutes)
#  - **Section 3:** Writing your API calls (approx 90 - 360 minutes)
#
# #### What You'll Turn In:
#  - A `.py` (not a Notebook!) file that contains the functions that you were prompted to create.  These should contain comments demonstrating why your code does what it does, and after it's run, the instructor should be able to make the appropriate function calls in Spyder or any other IDE.

# %% [markdown]
# ## Section 1:  Setting Up Your Developer Account

# %% [markdown]
# Most API's require you to do a little pre-work in order to be able to use them, so the first part of this homework assignment will be spent setting up your developer account so you have API Access.

# %% [markdown]
# **Step 1:  Create a Twitter Developer Account**
#
#  - Make sure you have a regular twitter account before you do this
#  - You can apply for a developer account here:  https://developer.twitter.com/en/apply-for-access
#   - Choose either a student or hobbyist/personal account
#   - **note:** these typically get approved right away, but it's possible you might have to wait a little bit......if 15 minutes pass, it might be best to take a break and come back in an hour or so.

# %% [markdown]
# **Step 2:  Create An App**
#
# You don't have to intend to build an official software program to have an app.....this is just a way for you to get authentication keys to use with the API.
#
#  - Go to the menu in the upper right hand corner and click on **Your Name** > **Apps**
#  - Choose **Create An App**
#  - You'll be prompted to enter some information about your app.  Don't worry too much about this, it can say almost anything.  You'll be prompted to list websites where it will be hosted...this can be anything for now.  Use https://generalassemb.ly if you're undecided about what to put.

# %% [markdown]
# **Step 3: Create Your API Tokens**
#
# Now that you have an app, you can use its API tokens to go ahead and make requests like we did in class 3.  Like a lot of API's, the Twitter API uses something called OAuth authentication.
#
# If you didn't wait until the night before this assignment was due and have a spare 30 minutes, you can read a little about it here: https://oauth.net/
#
# In any event, you need API tokens in order to make requests.  Do the following:
#
#  - Go to the **Apps** section of your developer portal
#  - Click on the **Details** button for the app that you just created
#  - Click on the **Keys & Tokens** tab:
#    - Two keys should already be given to you:  **API Key** & **API Secret Key**
#    - Two you have to generate:  **Access token** & **Access token secret**
#  - Generate your Access Token and Access Token Secret keys.  You'll need to write these down when you're done -- you can only see them once.
#
# Now you're ready to make requests to the Twitter api.  Everytime you make a request, you'll need to include the 4 tokens you just created.  (You can always regenerate them for whatever reason).

# %% [markdown]
# **Step 4:  Your First Request**
#
# To make requests to the Twitter API you're going to need a module which is **not** already pre-installed in Anaconda. You'll need to install it via PIP, which is python's package manager.  It's called `requests_oauthlib`.  You can install this via Anaconda Prompt or Terminal by simply typing in the command `pip install requests_oauthlib`, and then you'll be finished.
#
# The logistics of making an OAuth1 authenticated request are very similar to what was done in class 3, but with a few additional steps.  You can see how to do it here:  https://requests.readthedocs.io/en/master/user/authentication/#oauth-1-authentication.  The only thing you'll need to change is the info for your API tokens that are passed into the `OAuth1()` function.
#
# Try making a request to the following URL to confirm that you have things set up correctly: 'https://api.twitter.com/1.1/account/verify_credentials.json'

# %%
import requests
from requests_oauthlib import OAuth1

# %%
twitter_url = 'https://api.twitter.com/1.1/account/verify_credentials.json'
auth  = OAuth1('yRFD3WsOMN80LbeY3ugWxpduM', 'cuxQuVFpfFhIBcwNN9KPk3Qz3bOxH48ZRJJNFOTD91jeiyfX6W', '1288869541515350017-57MZSQRwrCSQ3XcZsbwKe1pGWg0Vcq', '8qnWLDyFTnn7oyUJ7Xo8NvuGKFRoM8waoLeg9bRKI3zso')
twitter_data = requests.get(twitter_url, auth=auth).json()

# %%
twitter_data
# Out:
# {'id': 1288869541515350017,
#  'id_str': '1288869541515350017',
#  'name': 'groovyluki',
#  'screen_name': 'groovyluki',
#  'location': '',
#  'description': 'just for coding',
#  'url': None,
#  'entities': {'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 0,
#  'friends_count': 0,
#  'listed_count': 0,
#  'created_at': 'Thu Jul 30 16:10:30 +0000 2020',
#  'favourites_count': 0,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'verified': False,
#  'statuses_count': 0,
#  'lang': None,
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': 'F5F8FA',
#  'profile_background_image_url': None,
#  'profile_background_image_url_https': None,
#  'profile_background_tile': False,
#  'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#  'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'has_extended_profile': True,
#  'default_profile': True,
#  'default_profile_image': True,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none',
#  'suspended': False,
#  'needs_phone_verification': False}

# %% [markdown]
# If you get your json object back, then you're good to go.

# %% [markdown]
# ## Section 2: Searching Tweets

# %% [markdown]
# Most websites you access will have a long string attached to the end of them that look something like this:  `http://thewebsite.com/?year=2019&color=golden%20yellow&user_id=48549395959438`.
#
# Most people have no reason to pay attention to any of this, but all the special symbols at the end are basically encoded commands that say 'return a website that displays x,y,z characteristics.'
#
# When accessing api data, it basically works the same way.

# %% [markdown]
# **Step 1:  Set Up Your First Query String**

# %% [markdown]
# If you go into Twitter and search for the term `Data Science`, you should be brought to a url that looks like this:  `https://twitter.com/search?q=Data%20Science&src=typed_query`
#
# If you'd like, you can drop the `&src=typed_query` from the url and still get the same results.
#
# There are some important details to pay attention to:
#
#  - Like class 3 when we worked with GitHub, there is a **base url**.  In this case it's `https://twitter.com/search`
#  - Whenever you enter a search for something, the base url will be followed by something that looks like `?q=My%20Search%20Term`
#   - The `?` marks the beginning of the query string.  This basically says 'initiate a request with whatever parameters that follow'
#   - The `q` is a **parameter**, essentially some condition to pass into the query string that determines what results will be given back to you.  In this case, `q` encodes the text you typed in into something the API can understand.
#
# **Useful Thing To Do Right Now:** Go back to the Twitter search page, and just try searching for different things, and notice what shows up after the `q=`.  Here are some questions to ask yourself:
#
#  - How are white spaces encoded?  Ie, if you search for `Jonathan Bechtel` in the search box, what shows up to account for the space between the two words?
#  - What about hash symbols?  If you search for `#MeToo`, `#GirlsWhoCode` or `#DataScience`, what happens with that `#` symbol?
#  - Once you get the hang of this, see if you can just re-create some searches yourself by creating the url directly, and bypassing the search box altogether.  Ie, be familiar enough with how searches are formatted that you know `https://twitter.com/search?q=%23DataScience` will take you to the same page as typing in `#DataScience` into the search box.
#
# Now, let's try and make a request for a search for `Data Science`.
#
# If you look at Twitter's docs, you'll see that the base url for the search API is `'https://api.twitter.com/1.1/search/tweets.json`
#
# This means you have to add the `?q=Whatever%20Word%20%Goes%20Here` to the end to complete the search.
#
# So go ahead, and see if you can create your API call for a search for the term `Data Science`.
#
# If you did it correctly, you should have a dictionary with a key called `statuses`, and it'll be a list with all of the tweets returned by your search.

# %%
import requests
from requests_oauthlib import OAuth1
tweets_url = 'https://api.twitter.com/1.1/search/tweets.json'
tweets_data = requests.get(tweets_url, auth=auth).json()
tweets_url
# Out:
# 'https://api.twitter.com/1.1/search/tweets.json'

# %%
twitterds_url = 'https://api.twitter.com/1.1/search/tweets.json?q=Data%20Science'
twitterds_data = requests.get(twitterds_url, auth=auth).json()

# %%
twitterds_data
# Out:
# {'statuses': [{'created_at': 'Fri Aug 07 13:48:53 +0000 2020',
#    'id': 1291733052813647872,
#    'id_str': '1291733052813647872',
#    'text': 'RT @steve_hanke: As I anticipated, the #Lira has passed the 7.00 TRY/USD mark &amp; is tanking. You can forget the official #inflation rate of…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Lira', 'indices': [39, 44]},
#      {'text': 'inflation', 'indices': [124, 134]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'steve_hanke',
#       'name': 'Prof. Steve Hanke',
#       'id': 863527548,
#       'id_str': '863527548',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 347231945,
#     'id_str': '347231945',
#     'name': 'Eren Suvari',
#     'screen_name': '4Suvariii',
#     'location': '',
#     'description': '...Türkiye Cumhuriyeti Vatandaşı...',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 24196,
#     'friends_count': 26573,
#     'listed_count': 38,
#     'created_at': 'Tue Aug 02 13:39:55 +0000 2011',
#     'favourites_count': 8599,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 465790,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/884778886986436608/my8iY492_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/884778886986436608/my8iY492_normal.jpg',
#     'profile_link_color': 'ABB8C2',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'regular'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Aug 07 13:30:00 +0000 2020',
#     'id': 1291728299299807233,
#     'id_str': '1291728299299807233',
#     'text': 'As I anticipated, the #Lira has passed the 7.00 TRY/USD mark &amp; is tanking. You can forget the official #inflation r… https://t.co/u7ACuuZU9Q',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Lira', 'indices': [22, 27]},
#       {'text': 'inflation', 'indices': [107, 117]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/u7ACuuZU9Q',
#        'expanded_url': 'https://twitter.com/i/web/status/1291728299299807233',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [121, 144]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 863527548,
#      'id_str': '863527548',
#      'name': 'Prof. Steve Hanke',
#      'screen_name': 'steve_hanke',
#      'location': 'Baltimore & Paris',
#      'description': 'Economist @JohnsHopkins | Sr Fellow & Director #TroubledCurrencies Project @CatoInstitute | @NRO | FX & Commodity Trader | Reagan White House | Views are my own',
#      'url': 'http://t.co/g7QtfrgXlV',
#      'entities': {'url': {'urls': [{'url': 'http://t.co/g7QtfrgXlV',
#          'expanded_url': 'http://bit.ly/SHH_Cato',
#          'display_url': 'bit.ly/SHH_Cato',
#          'indices': [0, 22]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 267696,
#      'friends_count': 11561,
#      'listed_count': 2269,
#      'created_at': 'Fri Oct 05 19:10:03 +0000 2012',
#      'favourites_count': 6938,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 30379,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/915395033871867905/3zbE7bAT_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/915395033871867905/3zbE7bAT_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/863527548/1465411293',
#      'profile_link_color': '0A0ACC',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 85,
#     'favorite_count': 197,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 85,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Aug 07 13:48:34 +0000 2020',
#    'id': 1291732971490336768,
#    'id_str': '1291732971490336768',
#    'text': 'RT @PHCSchoolOfAI: We have something special coming up!\n\nWe are organizing a Cloud Day on Saturday, 15th August.\nCome and learn how the clo…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'PHCSchoolOfAI',
#       'name': 'Port Harcourt City School of AI',
#       'id': 1033611209990451200,
#       'id_str': '1033611209990451200',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 236293492,
#     'id_str': '236293492',
#     'name': '†',
#     'screen_name': 'alentyler',
#     'location': 'Juypter Notebook † Power Query',
#     'description': '📌AI Exponential Thinker | Market Research Analyst & Consultant | Here Today, Forbes Tomorrow📌',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2404,
#     'friends_count': 1350,
#     'listed_count': 5,
#     'created_at': 'Mon Jan 10 07:34:55 +0000 2011',
#     'favourites_count': 22475,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 46426,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'FFF04D',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme19/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme19/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1249077078093434880/jPyyMo-P_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1249077078093434880/jPyyMo-P_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/236293492/1580428499',
#     'profile_link_color': '0099CC',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'F6FFD1',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Aug 07 06:56:13 +0000 2020',
#     'id': 1291629199359344640,
#     'id_str': '1291629199359344640',
#     'text': 'We have something special coming up!\n\nWe are organizing a Cloud Day on Saturday, 15th August.\nCome and learn how th… https://t.co/p0vGYM6mQy',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/p0vGYM6mQy',
#        'expanded_url': 'https://twitter.com/i/web/status/1291629199359344640',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1033611209990451200,
#      'id_str': '1033611209990451200',
#      'name': 'Port Harcourt City School of AI',
#      'screen_name': 'PHCSchoolOfAI',
#      'location': 'Port Harcourt, Nigeria',
#      'description': 'Making Machine Learning/Data Science education accessible to Nigerians.\n \nHelping people get into and excel in Data Science/Machine Learning.\n\nNot-for-profit.',
#      'url': 'https://t.co/XloQAlwAg8',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/XloQAlwAg8',
#          'expanded_url': 'https://phcschoolofai.org',
#          'display_url': 'phcschoolofai.org',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 620,
#      'friends_count': 140,
#      'listed_count': 5,
#      'created_at': 'Sun Aug 26 07:04:50 +0000 2018',
#      'favourites_count': 499,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 868,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1033615436003328000/H45RowBh_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1033615436003328000/H45RowBh_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1033611209990451200/1583833146',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 11,
#     'favorite_count': 20,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 11,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Aug 07 13:48:29 +0000 2020',
#    'id': 1291732952485965824,
#    'id_str': '1291732952485965824',
#    'text': 'RT @steve_hanke: As I anticipated, the #Lira has passed the 7.00 TRY/USD mark &amp; is tanking. You can forget the official #inflation rate of…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Lira', 'indices': [39, 44]},
#      {'text': 'inflation', 'indices': [124, 134]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'steve_hanke',
#       'name': 'Prof. Steve Hanke',
#       'id': 863527548,
#       'id_str': '863527548',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2211330782,
#     'id_str': '2211330782',
#     'name': 'Last Castle',
#     'screen_name': 'Buyap03',
#     'location': 'Melbourne, Victoria',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 83,
#     'friends_count': 1003,
#     'listed_count': 0,
#     'created_at': 'Sat Nov 23 20:54:59 +0000 2013',
#     'favourites_count': 1585,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 4053,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1169587476433948672/AJR--fIW_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1169587476433948672/AJR--fIW_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2211330782/1567716074',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Aug 07 13:30:00 +0000 2020',
#     'id': 1291728299299807233,
#     'id_str': '1291728299299807233',
#     'text': 'As I anticipated, the #Lira has passed the 7.00 TRY/USD mark &amp; is tanking. You can forget the official #inflation r… https://t.co/u7ACuuZU9Q',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Lira', 'indices': [22, 27]},
#       {'text': 'inflation', 'indices': [107, 117]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/u7ACuuZU9Q',
#        'expanded_url': 'https://twitter.com/i/web/status/1291728299299807233',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [121, 144]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 863527548,
#      'id_str': '863527548',
#      'name': 'Prof. Steve Hanke',
#      'screen_name': 'steve_hanke',
#      'location': 'Baltimore & Paris',
#      'description': 'Economist @JohnsHopkins | Sr Fellow & Director #TroubledCurrencies Project @CatoInstitute | @NRO | FX & Commodity Trader | Reagan White House | Views are my own',
#      'url': 'http://t.co/g7QtfrgXlV',
#      'entities': {'url': {'urls': [{'url': 'http://t.co/g7QtfrgXlV',
#          'expanded_url': 'http://bit.ly/SHH_Cato',
#          'display_url': 'bit.ly/SHH_Cato',
#          'indices': [0, 22]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 267696,
#      'friends_count': 11561,
#      'listed_count': 2269,
#      'created_at': 'Fri Oct 05 19:10:03 +0000 2012',
#      'favourites_count': 6938,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 30379,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/915395033871867905/3zbE7bAT_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/915395033871867905/3zbE7bAT_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/863527548/1465411293',
#      'profile_link_color': '0A0ACC',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 85,
#     'favorite_count': 197,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 85,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Aug 07 13:48:09 +0000 2020',
#    'id': 1291732866833973249,
#    'id_str': '1291732866833973249',
#    'text': 'RT @NiemanReports: How the “Beyonce of earthquakes” uses storytelling to explain science: @niemanstory takes a look at how seismologist @Dr…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'NiemanReports',
#       'name': 'Nieman Reports',
#       'id': 70706313,
#       'id_str': '70706313',
#       'indices': [3, 17]},
#      {'screen_name': 'niemanstory',
#       'name': 'Nieman Storyboard',
#       'id': 54781907,
#       'id_str': '54781907',
#       'indices': [90, 102]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 27606434,
#     'id_str': '27606434',
#     'name': 'James Geary',
#     'screen_name': 'JamesGeary',
#     'location': 'Boston (and London)',
#     'description': 'Harvard @niemanfdn @NiemanReports aphorisms (https://t.co/RzgGPEodzd https://t.co/CYRruhprV3) metaphor (https://t.co/LMBxhvg1ju) wit (https://t.co/uUyoZLLWgh)',
#     'url': 'http://t.co/SOzsBD67Ki',
#     'entities': {'url': {'urls': [{'url': 'http://t.co/SOzsBD67Ki',
#         'expanded_url': 'http://www.jamesgeary.com',
#         'display_url': 'jamesgeary.com',
#         'indices': [0, 22]}]},
#      'description': {'urls': [{'url': 'https://t.co/RzgGPEodzd',
#         'expanded_url': 'https://bit.ly/2zzAyfO',
#         'display_url': 'bit.ly/2zzAyfO',
#         'indices': [45, 68]},
#        {'url': 'https://t.co/CYRruhprV3',
#         'expanded_url': 'https://bit.ly/2L35xW1',
#         'display_url': 'bit.ly/2L35xW1',
#         'indices': [69, 92]},
#        {'url': 'https://t.co/LMBxhvg1ju',
#         'expanded_url': 'https://bit.ly/2uqmW0E',
#         'display_url': 'bit.ly/2uqmW0E',
#         'indices': [104, 127]},
#        {'url': 'https://t.co/uUyoZLLWgh',
#         'expanded_url': 'https://bit.ly/2uibLaU',
#         'display_url': 'bit.ly/2uibLaU',
#         'indices': [134, 157]}]}},
#     'protected': False,
#     'followers_count': 2413,
#     'friends_count': 1056,
#     'listed_count': 109,
#     'created_at': 'Mon Mar 30 08:38:28 +0000 2009',
#     'favourites_count': 390,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 5849,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C3E3EB',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/808376938322481154/dayp4_nA_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/808376938322481154/dayp4_nA_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/27606434/1575729398',
#     'profile_link_color': '3B94D9',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Aug 07 13:37:01 +0000 2020',
#     'id': 1291730063621263360,
#     'id_str': '1291730063621263360',
#     'text': 'How the “Beyonce of earthquakes” uses storytelling to explain science: @niemanstory takes a look at how seismologis… https://t.co/a9qVEnVQVV',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'niemanstory',
#        'name': 'Nieman Storyboard',
#        'id': 54781907,
#        'id_str': '54781907',
#        'indices': [71, 83]}],
#      'urls': [{'url': 'https://t.co/a9qVEnVQVV',
#        'expanded_url': 'https://twitter.com/i/web/status/1291730063621263360',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 70706313,
#      'id_str': '70706313',
#      'name': 'Nieman Reports',
#      'screen_name': 'NiemanReports',
#      'location': 'Cambridge, MA',
#      'description': "A publication of Harvard's @niemanfdn, @NiemanReports covers thought leadership in journalism. Winner of the Bart Richards Media Criticism award & @mirrorawards",
#      'url': 'http://t.co/jikS4bQjiL',
#      'entities': {'url': {'urls': [{'url': 'http://t.co/jikS4bQjiL',
#          'expanded_url': 'http://www.niemanreports.org/',
#          'display_url': 'niemanreports.org',
#          'indices': [0, 22]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 32568,
#      'friends_count': 1671,
#      'listed_count': 1710,
#      'created_at': 'Tue Sep 01 15:29:47 +0000 2009',
#      'favourites_count': 151,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 15304,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/512675218146349057/4DqKB5PB_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/512675218146349057/4DqKB5PB_normal.jpeg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/70706313/1595535068',
#      'profile_link_color': '990000',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': 'AAAAAA',
#      'profile_text_color': '000000',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 3,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Aug 07 13:48:05 +0000 2020',
#    'id': 1291732851386396673,
#    'id_str': '1291732851386396673',
#    'text': 'RT @steve_hanke: As I anticipated, the #Lira has passed the 7.00 TRY/USD mark &amp; is tanking. You can forget the official #inflation rate of…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Lira', 'indices': [39, 44]},
#      {'text': 'inflation', 'indices': [124, 134]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'steve_hanke',
#       'name': 'Prof. Steve Hanke',
#       'id': 863527548,
#       'id_str': '863527548',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 776551591675564032,
#     'id_str': '776551591675564032',
#     'name': 'MUSTAFA',
#     'screen_name': 'moephfin',
#     'location': '',
#     'description': 'Muharrem İnce galp ve YKS',
#     'url': 'https://t.co/Jq4WcDVPc6',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/Jq4WcDVPc6',
#         'expanded_url': 'https://www.instagram.com/mustafa.hazretleri/',
#         'display_url': 'instagram.com/mustafa.hazret…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 177,
#     'friends_count': 262,
#     'listed_count': 0,
#     'created_at': 'Thu Sep 15 22:41:42 +0000 2016',
#     'favourites_count': 4434,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2224,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1257619003025100800/vxts3gqV_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1257619003025100800/vxts3gqV_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/776551591675564032/1504055342',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Aug 07 13:30:00 +0000 2020',
#     'id': 1291728299299807233,
#     'id_str': '1291728299299807233',
#     'text': 'As I anticipated, the #Lira has passed the 7.00 TRY/USD mark &amp; is tanking. You can forget the official #inflation r… https://t.co/u7ACuuZU9Q',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Lira', 'indices': [22, 27]},
#       {'text': 'inflation', 'indices': [107, 117]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/u7ACuuZU9Q',
#        'expanded_url': 'https://twitter.com/i/web/status/1291728299299807233',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [121, 144]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 863527548,
#      'id_str': '863527548',
#      'name': 'Prof. Steve Hanke',
#      'screen_name': 'steve_hanke',
#      'location': 'Baltimore & Paris',
#      'description': 'Economist @JohnsHopkins | Sr Fellow & Director #TroubledCurrencies Project @CatoInstitute | @NRO | FX & Commodity Trader | Reagan White House | Views are my own',
#      'url': 'http://t.co/g7QtfrgXlV',
#      'entities': {'url': {'urls': [{'url': 'http://t.co/g7QtfrgXlV',
#          'expanded_url': 'http://bit.ly/SHH_Cato',
#          'display_url': 'bit.ly/SHH_Cato',
#          'indices': [0, 22]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 267696,
#      'friends_count': 11561,
#      'listed_count': 2269,
#      'created_at': 'Fri Oct 05 19:10:03 +0000 2012',
#      'favourites_count': 6938,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 30379,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/915395033871867905/3zbE7bAT_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/915395033871867905/3zbE7bAT_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/863527548/1465411293',
#      'profile_link_color': '0A0ACC',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 85,
#     'favorite_count': 197,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 85,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Aug 07 13:48:04 +0000 2020',
#    'id': 1291732846319742977,
#    'id_str': '1291732846319742977',
#    'text': '#RT @IncedoInc: Are wealth management companies taking the right steps to control advisor attrition and increase ad… https://t.co/fuuoQC4ubY',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'RT', 'indices': [0, 3]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'IncedoInc',
#       'name': 'Incedo',
#       'id': 491070192,
#       'id_str': '491070192',
#       'indices': [4, 14]}],
#     'urls': [{'url': 'https://t.co/fuuoQC4ubY',
#       'expanded_url': 'https://twitter.com/i/web/status/1291732846319742977',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 51416281,
#     'id_str': '51416281',
#     'name': 'apurv bhatnagar',
#     'screen_name': 'apurvbhatnagar',
#     'location': 'Hyderabad, Andhra Pradesh',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 44,
#     'friends_count': 162,
#     'listed_count': 15,
#     'created_at': 'Sat Jun 27 11:39:59 +0000 2009',
#     'favourites_count': 43,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 3811,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/736852493041164288/2_2www_i_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/736852493041164288/2_2www_i_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/51416281/1464514209',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Aug 07 13:48:04 +0000 2020',
#    'id': 1291732844696535041,
#    'id_str': '1291732844696535041',
#    'text': 'RT @steve_hanke: As I anticipated, the #Lira has passed the 7.00 TRY/USD mark &amp; is tanking. You can forget the official #inflation rate of…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Lira', 'indices': [39, 44]},
#      {'text': 'inflation', 'indices': [124, 134]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'steve_hanke',
#       'name': 'Prof. Steve Hanke',
#       'id': 863527548,
#       'id_str': '863527548',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1097486761708654592,
#     'id_str': '1097486761708654592',
#     'name': 'Tom🌍',
#     'screen_name': 'TominalYield',
#     'location': 'NY➡️Dallas ',
#     'description': 'Dissenting Financial Professional | Buckeye | Building @TGC_Macro',
#     'url': 'https://t.co/JmURXhSlu2',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/JmURXhSlu2',
#         'expanded_url': 'https://theglobalcapitalist.substack.com/',
#         'display_url': 'theglobalcapitalist.substack.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 154,
#     'friends_count': 1366,
#     'listed_count': 3,
#     'created_at': 'Mon Feb 18 13:23:29 +0000 2019',
#     'favourites_count': 3691,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1444,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1232427904853823488/LERJcXCc_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1232427904853823488/LERJcXCc_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1097486761708654592/1596166092',
#     'profile_link_color': 'ABB8C2',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Aug 07 13:30:00 +0000 2020',
#     'id': 1291728299299807233,
#     'id_str': '1291728299299807233',
#     'text': 'As I anticipated, the #Lira has passed the 7.00 TRY/USD mark &amp; is tanking. You can forget the official #inflation r… https://t.co/u7ACuuZU9Q',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Lira', 'indices': [22, 27]},
#       {'text': 'inflation', 'indices': [107, 117]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/u7ACuuZU9Q',
#        'expanded_url': 'https://twitter.com/i/web/status/1291728299299807233',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [121, 144]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 863527548,
#      'id_str': '863527548',
#      'name': 'Prof. Steve Hanke',
#      'screen_name': 'steve_hanke',
#      'location': 'Baltimore & Paris',
#      'description': 'Economist @JohnsHopkins | Sr Fellow & Director #TroubledCurrencies Project @CatoInstitute | @NRO | FX & Commodity Trader | Reagan White House | Views are my own',
#      'url': 'http://t.co/g7QtfrgXlV',
#      'entities': {'url': {'urls': [{'url': 'http://t.co/g7QtfrgXlV',
#          'expanded_url': 'http://bit.ly/SHH_Cato',
#          'display_url': 'bit.ly/SHH_Cato',
#          'indices': [0, 22]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 267696,
#      'friends_count': 11561,
#      'listed_count': 2269,
#      'created_at': 'Fri Oct 05 19:10:03 +0000 2012',
#      'favourites_count': 6938,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 30379,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/915395033871867905/3zbE7bAT_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/915395033871867905/3zbE7bAT_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/863527548/1465411293',
#      'profile_link_color': '0A0ACC',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 85,
#     'favorite_count': 197,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 85,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Aug 07 13:47:54 +0000 2020',
#    'id': 1291732806620581888,
#    'id_str': '1291732806620581888',
#    'text': 'RT @nikefootball: Countless lab hours, athlete insights, and prototypes all add up to our most data-driven boot ever. Learn about the scien…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'nikefootball',
#       'name': 'Nike Football',
#       'id': 41147159,
#       'id_str': '41147159',
#       'indices': [3, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 902347145021411328,
#     'id_str': '902347145021411328',
#     'name': '○m○bankole🌍',
#     'screen_name': 'omobankole1',
#     'location': '',
#     'description': '👷 web developer || Islam🕋 || #CFC 💙 || #wizkid ⭐ || #CR7 || I follow back 🙏',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3307,
#     'friends_count': 3286,
#     'listed_count': 0,
#     'created_at': 'Tue Aug 29 01:48:18 +0000 2017',
#     'favourites_count': 47247,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 16990,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1262151262008758273/YAvHQNnz_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1262151262008758273/YAvHQNnz_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/902347145021411328/1555936150',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Mon Aug 03 07:59:53 +0000 2020',
#     'id': 1290195673434828804,
#     'id_str': '1290195673434828804',
#     'text': 'Countless lab hours, athlete insights, and prototypes all add up to our most data-driven boot ever. Learn about the… https://t.co/yZPdIUHCB8',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/yZPdIUHCB8',
#        'expanded_url': 'https://twitter.com/i/web/status/1290195673434828804',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 41147159,
#      'id_str': '41147159',
#      'name': 'Nike Football',
#      'screen_name': 'nikefootball',
#      'location': 'Worldwide',
#      'description': '',
#      'url': 'https://t.co/1skRjEhgUn',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/1skRjEhgUn',
#          'expanded_url': 'http://gonike.me/nikefootball',
#          'display_url': 'gonike.me/nikefootball',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 3620646,
#      'friends_count': 209,
#      'listed_count': 4889,
#      'created_at': 'Tue May 19 16:16:20 +0000 2009',
#      'favourites_count': 1599,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 46361,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1278494917174587392/TKQueGE7_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1278494917174587392/TKQueGE7_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/41147159/1593651917',
#      'profile_link_color': 'E81C4F',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 220,
#     'favorite_count': 1425,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 220,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Aug 07 13:47:28 +0000 2020',
#    'id': 1291732697602240512,
#    'id_str': '1291732697602240512',
#    'text': '@lennoxchong When making public majority decisions and reporting news I think data, science and stats should be the… https://t.co/emL6or89P1',
# ...
#        'expanded_url': 'https://twitter.com/i/web/status/1291728299299807233',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [121, 144]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 863527548,
#      'id_str': '863527548',
#      'name': 'Prof. Steve Hanke',
#      'screen_name': 'steve_hanke',
#      'location': 'Baltimore & Paris',
#      'description': 'Economist @JohnsHopkins | Sr Fellow & Director #TroubledCurrencies Project @CatoInstitute | @NRO | FX & Commodity Trader | Reagan White House | Views are my own',
#      'url': 'http://t.co/g7QtfrgXlV',
#      'entities': {'url': {'urls': [{'url': 'http://t.co/g7QtfrgXlV',
#          'expanded_url': 'http://bit.ly/SHH_Cato',
#          'display_url': 'bit.ly/SHH_Cato',
#          'indices': [0, 22]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 267696,
#      'friends_count': 11561,
#      'listed_count': 2269,
#      'created_at': 'Fri Oct 05 19:10:03 +0000 2012',
#      'favourites_count': 6938,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 30379,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/915395033871867905/3zbE7bAT_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/915395033871867905/3zbE7bAT_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/863527548/1465411293',
#      'profile_link_color': '0A0ACC',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 85,
#     'favorite_count': 197,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 85,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Aug 07 13:46:56 +0000 2020',
#    'id': 1291732561069248512,
#    'id_str': '1291732561069248512',
#    'text': 'RT @steve_hanke: As I anticipated, the #Lira has passed the 7.00 TRY/USD mark &amp; is tanking. You can forget the official #inflation rate of…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Lira', 'indices': [39, 44]},
#      {'text': 'inflation', 'indices': [124, 134]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'steve_hanke',
#       'name': 'Prof. Steve Hanke',
#       'id': 863527548,
#       'id_str': '863527548',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2429639591,
#     'id_str': '2429639591',
#     'name': 'Hatice ARSLAN',
#     'screen_name': 'HaticeArslan79',
#     'location': 'Evren/karadelik',
#     'description': 'Fûtursuz dizelerin , destûrsuz şairiyim...\n\n    #Nihilist #Felsefe #Anarşist\n                                         her yaşam kutsaldır',
#     'url': 'https://t.co/1j3CUauSwT',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/1j3CUauSwT',
#         'expanded_url': 'http://Patilicanlar.org',
#         'display_url': 'Patilicanlar.org',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 871,
#     'friends_count': 1026,
#     'listed_count': 1,
#     'created_at': 'Sat Mar 22 21:27:36 +0000 2014',
#     'favourites_count': 106683,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 66031,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1277328923181944836/NzBdZN1v_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1277328923181944836/NzBdZN1v_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2429639591/1585347484',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Aug 07 13:30:00 +0000 2020',
#     'id': 1291728299299807233,
#     'id_str': '1291728299299807233',
#     'text': 'As I anticipated, the #Lira has passed the 7.00 TRY/USD mark &amp; is tanking. You can forget the official #inflation r… https://t.co/u7ACuuZU9Q',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Lira', 'indices': [22, 27]},
#       {'text': 'inflation', 'indices': [107, 117]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/u7ACuuZU9Q',
#        'expanded_url': 'https://twitter.com/i/web/status/1291728299299807233',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [121, 144]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 863527548,
#      'id_str': '863527548',
#      'name': 'Prof. Steve Hanke',
#      'screen_name': 'steve_hanke',
#      'location': 'Baltimore & Paris',
#      'description': 'Economist @JohnsHopkins | Sr Fellow & Director #TroubledCurrencies Project @CatoInstitute | @NRO | FX & Commodity Trader | Reagan White House | Views are my own',
#      'url': 'http://t.co/g7QtfrgXlV',
#      'entities': {'url': {'urls': [{'url': 'http://t.co/g7QtfrgXlV',
#          'expanded_url': 'http://bit.ly/SHH_Cato',
#          'display_url': 'bit.ly/SHH_Cato',
#          'indices': [0, 22]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 267696,
#      'friends_count': 11561,
#      'listed_count': 2269,
#      'created_at': 'Fri Oct 05 19:10:03 +0000 2012',
#      'favourites_count': 6938,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 30379,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/915395033871867905/3zbE7bAT_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/915395033871867905/3zbE7bAT_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/863527548/1465411293',
#      'profile_link_color': '0A0ACC',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 85,
#     'favorite_count': 197,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 85,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Aug 07 13:46:54 +0000 2020',
#    'id': 1291732551636328448,
#    'id_str': '1291732551636328448',
#    'text': 'RT @cloudthat: Learn how to get your dream job in Data Science with Microsoft Azure AI/ML Certifications in our next webinar by our CEO and…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'cloudthat',
#       'name': 'CloudThat',
#       'id': 454741064,
#       'id_str': '454741064',
#       'indices': [3, 13]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://azure.microsoft.com/en-us/services/app-service/logic/" rel="nofollow">Microsoft Azure Logic Apps</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 491383977,
#     'id_str': '491383977',
#     'name': 'Prarthit Mehta',
#     'screen_name': 'PrarthitM',
#     'location': 'Bangaluru',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 70,
#     'friends_count': 124,
#     'listed_count': 0,
#     'created_at': 'Mon Feb 13 15:40:02 +0000 2012',
#     'favourites_count': 30,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 287,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/3009906625/d6b3296d4db74745cfd135286351ebdc_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3009906625/d6b3296d4db74745cfd135286351ebdc_normal.jpeg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/491383977/1356257797',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Aug 07 13:18:12 +0000 2020',
#     'id': 1291725331519303680,
#     'id_str': '1291725331519303680',
#     'text': 'Learn how to get your dream job in Data Science with Microsoft Azure AI/ML Certifications in our next webinar by ou… https://t.co/osBXbZPpb3',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/osBXbZPpb3',
#        'expanded_url': 'https://twitter.com/i/web/status/1291725331519303680',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 454741064,
#      'id_str': '454741064',
#      'name': 'CloudThat',
#      'screen_name': 'cloudthat',
#      'location': '',
#      'description': 'Focused on Consulting on Cloud and Big Data. Pioneers in Training on Cloud Computing & AWS in the United States and India.',
#      'url': 'https://t.co/Hi8mnXExnE',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/Hi8mnXExnE',
#          'expanded_url': 'https://cloudthat.in/',
#          'display_url': 'cloudthat.in',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 542,
#      'friends_count': 57,
#      'listed_count': 70,
#      'created_at': 'Wed Jan 04 10:00:11 +0000 2012',
#      'favourites_count': 23,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 2467,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C3D3DE',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/763261464396173313/rTtQNyac_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/763261464396173313/rTtQNyac_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/454741064/1519903411',
#      'profile_link_color': '143EE3',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': 'DDFFCC',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.113,
#   'max_id': 1291733052813647872,
#   'max_id_str': '1291733052813647872',
#   'next_results': '?max_id=1291732551636328447&q=Data%20Science&include_entities=1',
#   'query': 'Data+Science',
#   'refresh_url': '?since_id=1291733052813647872&q=Data%20Science&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
twitter_datascience = [tweet for datascience in twitterds_data for tweet in datascience]

# %% [markdown]
# For good measure, try doing a search for tweets relating to `#MeToo` as well.

# %%
twitter_metoo = 'https://api.twitter.com/1.1/search/tweets.json?q=%23metoo&src=typed_query'
twitter_metoo_data = requests.get(twitter_metoo, auth=auth).json()

# %%
twitter_metoo_data
# Out:
# {'statuses': [{'created_at': 'Thu Aug 06 15:45:40 +0000 2020',
#    'id': 1291400054087938048,
#    'id_str': '1291400054087938048',
#    'text': '#metoo https://t.co/QMClqWM1Kx',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'metoo', 'indices': [0, 6]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/QMClqWM1Kx',
#       'expanded_url': 'https://twitter.com/EricMMatheny/status/1291360701215313921',
#       'display_url': 'twitter.com/EricMMatheny/s…',
#       'indices': [7, 30]}]},
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 810635508166574082,
#     'id_str': '810635508166574082',
#     'name': 'Steve',
#     'screen_name': 'SteveCinSoCal',
#     'location': 'Southern California',
#     'description': '#ArmyVet #HarleyRider #PrivatePilot #BlackBelt #Conservative - #Trump2020 #MAGA #ProLife. Followed by @GenFlynn, Friends with Bill - 32 Years',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 8549,
#     'friends_count': 8988,
#     'listed_count': 1,
#     'created_at': 'Sun Dec 18 23:59:00 +0000 2016',
#     'favourites_count': 42186,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 40662,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1008764634856243200/npm4EFC3_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1008764634856243200/npm4EFC3_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1291360701215313921,
#    'quoted_status_id_str': '1291360701215313921',
#    'quoted_status': {'created_at': 'Thu Aug 06 13:09:18 +0000 2020',
#     'id': 1291360701215313921,
#     'id_str': '1291360701215313921',
#     'text': 'If Portland wanted to secede from the United States I’d be perfectly okay with that.',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 2730264319,
#      'id_str': '2730264319',
#      'name': 'Eric Matheny🎙',
#      'screen_name': 'EricMMatheny',
#      'location': 'Broward County, Florida',
#      'description': 'Attorney • Podcaster • Social Commentator Cohost of “Bob & Eric Save America” on iTunes: https://t.co/1QAhin5MIL Spotify: https://t.co/DnldtS1Zyz Google: https://t.co/qkyKvFeXKt',
#      'url': 'https://t.co/rkg253o9jJ',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/rkg253o9jJ',
#          'expanded_url': 'http://Patreon.com/BobAndEric',
#          'display_url': 'Patreon.com/BobAndEric',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/1QAhin5MIL',
#          'expanded_url': 'http://rb.gy/ckwpnf',
#          'display_url': 'rb.gy/ckwpnf',
#          'indices': [89, 112]},
#         {'url': 'https://t.co/DnldtS1Zyz',
#          'expanded_url': 'http://rb.gy/hx6vwz',
#          'display_url': 'rb.gy/hx6vwz',
#          'indices': [122, 145]},
#         {'url': 'https://t.co/qkyKvFeXKt',
#          'expanded_url': 'http://rb.gy/grjotq',
#          'display_url': 'rb.gy/grjotq',
#          'indices': [154, 177]}]}},
#      'protected': False,
#      'followers_count': 106968,
#      'friends_count': 98573,
#      'listed_count': 107,
#      'created_at': 'Wed Aug 13 20:18:03 +0000 2014',
#      'favourites_count': 147592,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 144963,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1236843449539866625/zlP_hvtM_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1236843449539866625/zlP_hvtM_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2730264319/1594406498',
#      'profile_link_color': '143C4A',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 158,
#     'favorite_count': 525,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'und'},
#   {'created_at': 'Thu Aug 06 15:45:24 +0000 2020',
#    'id': 1291399984919851010,
#    'id_str': '1291399984919851010',
#    'text': 'RT @Lrihendry: I’m starting a whole new me too movement. I’m voting for President Trump no matter what! \n\nTYPE #MeToo if you’re with me!',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MeToo', 'indices': [111, 117]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Lrihendry',
#       'name': 'LORI HENDRY',
#       'id': 129235890,
#       'id_str': '129235890',
#       'indices': [3, 13]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1285362566135521280,
#     'id_str': '1285362566135521280',
#     'name': 'Jeffrey Davison',
#     'screen_name': 'JeffreyDaviso13',
#     'location': 'Texas, USA',
#     'description': 'Conservative, Patriot, MAGA, Texan',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 965,
#     'friends_count': 1821,
#     'listed_count': 0,
#     'created_at': 'Mon Jul 20 23:55:10 +0000 2020',
#     'favourites_count': 9147,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 11140,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1286117637039284225/s0PwSEIP_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1286117637039284225/s0PwSEIP_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1285362566135521280/1595469508',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Jul 26 13:41:30 +0000 2020',
#     'id': 1287382541427716097,
#     'id_str': '1287382541427716097',
#     'text': 'I’m starting a whole new me too movement. I’m voting for President Trump no matter what! \n\nTYPE #MeToo if you’re with me!',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'MeToo', 'indices': [96, 102]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 129235890,
#      'id_str': '129235890',
#      'name': 'LORI HENDRY',
#      'screen_name': 'Lrihendry',
#      'location': '',
#      'description': 'Digital Keyboard Warrior for @realDonaldTrump•Proudly RTed by President Trump•purveyor of truth •Views are my own #AmericaFirst #TRUMP2020 #KAG 🚫NO FF TRAINS',
#      'url': 'https://t.co/ft5y4ZcxFG',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/ft5y4ZcxFG',
#          'expanded_url': 'http://www.redwhiteandLori.com',
#          'display_url': 'redwhiteandLori.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 356336,
#      'friends_count': 8167,
#      'listed_count': 1877,
#      'created_at': 'Sat Apr 03 16:27:01 +0000 2010',
#      'favourites_count': 180016,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 344025,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1256326403986948097/iNcaNXQi_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1256326403986948097/iNcaNXQi_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/129235890/1564319866',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7952,
#     'favorite_count': 35422,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7952,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Aug 06 15:45:23 +0000 2020',
#    'id': 1291399983091126274,
#    'id_str': '1291399983091126274',
#    'text': '✔️ [ⒸⒸ]➥ De que vuelan vuelan: ¿Zapatos rojos? 👈😲👇 https://t.co/nRobuRGmcr | #actress #actresses #actor #Cabal… https://t.co/Io17SDtRzU',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'actress', 'indices': [77, 85]},
#      {'text': 'actresses', 'indices': [86, 96]},
#      {'text': 'actor', 'indices': [97, 103]},
#      {'text': 'Cabal', 'indices': [104, 110]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/nRobuRGmcr',
#       'expanded_url': 'http://bit.ly/3g0t71U',
#       'display_url': 'bit.ly/3g0t71U',
#       'indices': [51, 74]},
#      {'url': 'https://t.co/Io17SDtRzU',
#       'expanded_url': 'https://twitter.com/i/web/status/1291399983091126274',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [112, 135]}]},
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 575410217,
#     'id_str': '575410217',
#     'name': '© CLUB CRITICД',
#     'screen_name': 'clubcritica',
#     'location': '',
#     'description': '[ⒸⒸ]➥ Internet es amplio y todos estamos dentro. Sea original. RT y #Noticias programadas. #Cine #TV #Política en CLUB CRITICД \nIG: @clubcritica',
#     'url': 'https://t.co/paaBQdhn7D',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/paaBQdhn7D',
#         'expanded_url': 'http://clubcritica.wordpress.com',
#         'display_url': 'clubcritica.wordpress.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 381,
#     'friends_count': 1,
#     'listed_count': 91,
#     'created_at': 'Wed May 09 14:44:33 +0000 2012',
#     'favourites_count': 784,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 588011,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '131516',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1280517066668281858/Q_zNQkJV_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1280517066668281858/Q_zNQkJV_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/575410217/1492492249',
#     'profile_link_color': '009999',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'EFEFEF',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'es'},
#   {'created_at': 'Thu Aug 06 15:44:59 +0000 2020',
#    'id': 1291399881278423040,
#    'id_str': '1291399881278423040',
#    'text': '@obianuju Yet the #metoo or #timesup movement, Alyssa Milano, Michelle Obama, Reese Witherspoon, won’t say a thing… https://t.co/CjjVkXvIJj',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'metoo', 'indices': [18, 24]},
#      {'text': 'timesup', 'indices': [28, 36]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'obianuju',
#       'name': 'Obianuju Ekeocha',
#       'id': 33280581,
#       'id_str': '33280581',
#       'indices': [0, 9]}],
#     'urls': [{'url': 'https://t.co/CjjVkXvIJj',
#       'expanded_url': 'https://twitter.com/i/web/status/1291399881278423040',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1291394877457039360,
#    'in_reply_to_status_id_str': '1291394877457039360',
#    'in_reply_to_user_id': 33280581,
#    'in_reply_to_user_id_str': '33280581',
#    'in_reply_to_screen_name': 'obianuju',
#    'user': {'id': 227085972,
#     'id_str': '227085972',
#     'name': 'CalTexMix',
#     'screen_name': 'CalTexMix',
#     'location': '',
#     'description': 'Former blue dog dem, turned independent, now constitutionalist. No tolerance for group think or single issues. Vote the best, not the coronated. #WalkAway',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 278,
#     'friends_count': 238,
#     'listed_count': 4,
#     'created_at': 'Wed Dec 15 21:42:15 +0000 2010',
#     'favourites_count': 18337,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 29592,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000692010418/50c20e65ed95235e0891379b2960cada_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000692010418/50c20e65ed95235e0891379b2960cada_normal.jpeg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Aug 06 15:43:52 +0000 2020',
#    'id': 1291399599744339970,
#    'id_str': '1291399599744339970',
#    'text': 'Para algo bueno que le trae Ágata a Elías... Muy a favor de las de pelis de leer.  Ah, y del #metoo #MercadoCentral https://t.co/L45i4Wr8OQ',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'metoo', 'indices': [93, 99]},
#      {'text': 'MercadoCentral', 'indices': [100, 115]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/L45i4Wr8OQ',
#       'expanded_url': 'https://twitter.com/MiriansTweets/status/1291393713458085888',
#       'display_url': 'twitter.com/MiriansTweets/…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3423843263,
#     'id_str': '3423843263',
#     'name': 'Ana',
#     'screen_name': 'guiltypleased',
#     'location': '',
#     'description': 'I watch things on TV. Intersectional feminist.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 137,
#     'friends_count': 370,
#     'listed_count': 4,
#     'created_at': 'Sat Aug 15 10:59:35 +0000 2015',
#     'favourites_count': 2251,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 7442,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/632507437266944000/Xsl05EXB_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/632507437266944000/Xsl05EXB_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1291393713458085888,
#    'quoted_status_id_str': '1291393713458085888',
#    'quoted_status': {'created_at': 'Thu Aug 06 15:20:28 +0000 2020',
#     'id': 1291393713458085888,
#     'id_str': '1291393713458085888',
#     'text': 'jajaja que bueno Elias, una peli de leer #MercadoCentral',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'MercadoCentral', 'indices': [41, 56]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1209158949292969985,
#      'id_str': '1209158949292969985',
#      'name': "Mirian's",
#      'screen_name': 'MiriansTweets',
#      'location': '',
#      'description': 'Soy fotógrafa y un poco youtuber, aterrizo aqui para contar y opinar lo que me parezca\nCinefila y seriefila a tope!! (sobre todo hispano)',
#      'url': 'https://t.co/WUJsg6Lfq5',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/WUJsg6Lfq5',
#          'expanded_url': 'https://www.youtube.com/channel/UCl7jBOCFPRDINb_1zj_wX0A/videos?view_as=subscriber',
#          'display_url': 'youtube.com/channel/UCl7jB…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 28,
#      'friends_count': 49,
#      'listed_count': 0,
#      'created_at': 'Mon Dec 23 17:09:03 +0000 2019',
#      'favourites_count': 6982,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 2725,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1284145090676559873/Pbg7VgUR_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1284145090676559873/Pbg7VgUR_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1209158949292969985/1594999024',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'es'},
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'es'},
#   {'created_at': 'Thu Aug 06 15:43:50 +0000 2020',
#    'id': 1291399591997448192,
#    'id_str': '1291399591997448192',
#    'text': "RT @KaceyKells: ⭐⭐⭐⭐⭐ Albert Vandersteeg's review of Kellcey #Book #Kellcey #KaceyKells #bookreview #metoo\n https://t.co/I0pX4LSsOT",
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Book', 'indices': [61, 66]},
#      {'text': 'Kellcey', 'indices': [67, 75]},
#      {'text': 'KaceyKells', 'indices': [76, 87]},
#      {'text': 'bookreview', 'indices': [88, 99]},
#      {'text': 'metoo', 'indices': [100, 106]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'KaceyKells',
#       'name': 'Kacey Kells',
#       'id': 1497738242,
#       'id_str': '1497738242',
#       'indices': [3, 14]}],
#     'urls': [{'url': 'https://t.co/I0pX4LSsOT',
#       'expanded_url': 'https://kaceykells.wixsite.com/kellcey/single-post/2020/08/06/%E2%AD%90%E2%AD%90%E2%AD%90%E2%AD%90%E2%AD%90-Albert-Vandersteegs-review-of-Kellcey',
#       'display_url': 'kaceykells.wixsite.com/kellcey/single…',
#       'indices': [108, 131]}]},
#    'metadata': {'iso_language_code': 'nl', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 844383749332766725,
#     'id_str': '844383749332766725',
#     'name': 'K. Z. Howell',
#     'screen_name': 'KZ_Howell',
#     'location': 'Southwest Tennessee',
#     'description': 'Father, Soldier, Author and Redneck Philosopher.\nI write Science Fiction, History and Thrillers.\n\nI unfollow back.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 9606,
#     'friends_count': 4605,
#     'listed_count': 91,
#     'created_at': 'Wed Mar 22 03:02:28 +0000 2017',
#     'favourites_count': 132003,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 137891,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/994539256713433088/iO9mTgyz_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/994539256713433088/iO9mTgyz_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/844383749332766725/1534819703',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Aug 06 08:37:32 +0000 2020',
#     'id': 1291292308474863617,
#     'id_str': '1291292308474863617',
#     'text': "⭐⭐⭐⭐⭐ Albert Vandersteeg's review of Kellcey #Book #Kellcey #KaceyKells #bookreview #metoo\n https://t.co/I0pX4LSsOT",
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'Book', 'indices': [45, 50]},
#       {'text': 'Kellcey', 'indices': [51, 59]},
#       {'text': 'KaceyKells', 'indices': [60, 71]},
#       {'text': 'bookreview', 'indices': [72, 83]},
#       {'text': 'metoo', 'indices': [84, 90]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/I0pX4LSsOT',
#        'expanded_url': 'https://kaceykells.wixsite.com/kellcey/single-post/2020/08/06/%E2%AD%90%E2%AD%90%E2%AD%90%E2%AD%90%E2%AD%90-Albert-Vandersteegs-review-of-Kellcey',
#        'display_url': 'kaceykells.wixsite.com/kellcey/single…',
#        'indices': [92, 115]}]},
#     'metadata': {'iso_language_code': 'nl', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1497738242,
#      'id_str': '1497738242',
#      'name': 'Kacey Kells',
#      'screen_name': 'KaceyKells',
#      'location': 'London UK',
#      'description': "Author of 'KELLCEY'. From Victoria BC, I now live in London UK. I love fashion, books and feel concerned with women's rights #MeToo 🇨🇦🇬🇧",
#      'url': 'https://t.co/KQYqIU5EE5',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KQYqIU5EE5',
#          'expanded_url': 'http://kaceykells.wixsite.com/kellcey',
#          'display_url': 'kaceykells.wixsite.com/kellcey',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 13119,
#      'friends_count': 8875,
#      'listed_count': 204,
#      'created_at': 'Mon Jun 10 08:34:29 +0000 2013',
#      'favourites_count': 33933,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 404360,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'FFFFFF',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme11/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme11/bg.gif',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/529233115131019264/qrzdJ1l3_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/529233115131019264/qrzdJ1l3_normal.png',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1497738242/1560292018',
#      'profile_link_color': '7BB3DC',
#      'profile_sidebar_border_color': 'FFA400',
#      'profile_sidebar_fill_color': 'E32820',
#      'profile_text_color': '843AA9',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 9,
#     'favorite_count': 9,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'nl'},
#    'is_quote_status': False,
#    'retweet_count': 9,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'nl'},
#   {'created_at': 'Thu Aug 06 15:43:44 +0000 2020',
#    'id': 1291399565992763394,
#    'id_str': '1291399565992763394',
#    'text': '@kaivaaja @MailVeikko @MikaelJungner Niin selittääkin 100%\n\nKoska sulle kelpaa e nainen on huora kun se ei anna ja… https://t.co/E42C5gGWLd',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'kaivaaja',
#       'name': 'Kaivaaja',
#       'id': 1037919390128386048,
#       'id_str': '1037919390128386048',
#       'indices': [0, 9]},
#      {'screen_name': 'MailVeikko',
#       'name': 'Veikko Vallin',
#       'id': 630999765,
#       'id_str': '630999765',
#       'indices': [10, 21]},
#      {'screen_name': 'MikaelJungner',
#       'name': 'Mikael Jungner',
#       'id': 27093184,
#       'id_str': '27093184',
#       'indices': [22, 36]}],
#     'urls': [{'url': 'https://t.co/E42C5gGWLd',
#       'expanded_url': 'https://twitter.com/i/web/status/1291399565992763394',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'fi', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1283252195593461761,
#    'in_reply_to_status_id_str': '1283252195593461761',
#    'in_reply_to_user_id': 1037919390128386048,
#    'in_reply_to_user_id_str': '1037919390128386048',
#    'in_reply_to_screen_name': 'kaivaaja',
#    'user': {'id': 3774443183,
#     'id_str': '3774443183',
#     'name': 'Koira',
#     'screen_name': 'heidi_karinen',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 0,
#     'friends_count': 1,
#     'listed_count': 0,
#     'created_at': 'Fri Sep 25 20:07:30 +0000 2015',
#     'favourites_count': 3165,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 4924,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': True,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'fi'},
#   {'created_at': 'Thu Aug 06 15:43:24 +0000 2020',
#    'id': 1291399484828717058,
#    'id_str': '1291399484828717058',
#    'text': '@GoossensJitske @LizeDuppen #MeToo',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MeToo', 'indices': [28, 34]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'GoossensJitske',
#       'name': 'Jitske Goossens',
#       'id': 1120727651164012546,
#       'id_str': '1120727651164012546',
#       'indices': [0, 15]},
#      {'screen_name': 'LizeDuppen',
#       'name': 'lize duppen',
#       'id': 1267434328801361920,
#       'id_str': '1267434328801361920',
#       'indices': [16, 27]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1291293872971186177,
#    'in_reply_to_status_id_str': '1291293872971186177',
#    'in_reply_to_user_id': 1120727651164012546,
#    'in_reply_to_user_id_str': '1120727651164012546',
#    'in_reply_to_screen_name': 'GoossensJitske',
#    'user': {'id': 956597259143180288,
#     'id_str': '956597259143180288',
#     'name': 'Stijn Saeys',
#     'screen_name': 'Stijn_Saeys',
#     'location': 'Hamme, België',
#     'description': 'Maarten Westhof',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 56,
#     'friends_count': 149,
#     'listed_count': 0,
#     'created_at': 'Thu Jan 25 18:38:54 +0000 2018',
#     'favourites_count': 95,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 24,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1289666935261745152/HHzbEen2_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1289666935261745152/HHzbEen2_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/956597259143180288/1595796612',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'und'},
#   {'created_at': 'Thu Aug 06 15:43:09 +0000 2020',
#    'id': 1291399421704507394,
#    'id_str': '1291399421704507394',
#    'text': 'RT @FirstThemNEWS: Sexual assualt victim takes her life after receiving backlash, for speaking out against her attack.\n\nAnother victim kill…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'FirstThemNEWS',
#       'name': '#FirstThem NEWS🇺🇸',
#       'id': 996339202647252992,
#       'id_str': '996339202647252992',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 49668104,
#     'id_str': '49668104',
#     'name': 'FreedomFirst&Now',
#     'screen_name': 'i_m_sovereign',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 76,
#     'friends_count': 417,
#     'listed_count': 1,
#     'created_at': 'Mon Jun 22 15:50:48 +0000 2009',
#     'favourites_count': 9684,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 10791,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1711344291/227559_1046459487587_1408655756_141675_1671_n_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1711344291/227559_1046459487587_1408655756_141675_1671_n_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Aug 06 14:23:43 +0000 2020',
#     'id': 1291379429374009348,
#     'id_str': '1291379429374009348',
#     'text': 'Sexual assualt victim takes her life after receiving backlash, for speaking out against her attack.\n\nAnother victim… https://t.co/Fz8l2N8xvD',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/Fz8l2N8xvD',
#        'expanded_url': 'https://twitter.com/i/web/status/1291379429374009348',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 996339202647252992,
#      'id_str': '996339202647252992',
#      'name': '#FirstThem NEWS🇺🇸',
#      'screen_name': 'FirstThemNEWS',
#      'location': 'Gadsden’s Wharf, S. Carolina',
#      'description': '#FBA🇺🇸Journalist/Activists use #FirstThem to DESTROY the myth of “Black Rape.” Meanwhile .... the MSM “gaslights” #MeToo w/under-reporting of Sexual Violence.',
#      'url': 'https://t.co/A5PIzepjhZ',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/A5PIzepjhZ',
#          'expanded_url': 'https://firstthemNEWS.com/blog-metoo',
#          'display_url': 'firstthemNEWS.com/blog-metoo',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 6558,
#      'friends_count': 88,
#      'listed_count': 25,
#      'created_at': 'Tue May 15 10:39:11 +0000 2018',
#      'favourites_count': 9457,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 8054,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1241436189963325440/8i9jSYU2_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1241436189963325440/8i9jSYU2_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/996339202647252992/1581849921',
#      'profile_link_color': 'E81C4F',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 5,
#     'favorite_count': 10,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 5,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Aug 06 15:42:19 +0000 2020',
#    'id': 1291399211536261122,
#    'id_str': '1291399211536261122',
#    'text': '@BastiFaun #MeToo',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MeToo', 'indices': [11, 17]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'BastiFaun',
#       'name': 'Basti der Faun',
#       'id': 1239141691526975489,
#       'id_str': '1239141691526975489',
#       'indices': [0, 10]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1291396108040757249,
#    'in_reply_to_status_id_str': '1291396108040757249',
#    'in_reply_to_user_id': 1239141691526975489,
#    'in_reply_to_user_id_str': '1239141691526975489',
#    'in_reply_to_screen_name': 'BastiFaun',
#    'user': {'id': 998628224212094977,
#     'id_str': '998628224212094977',
#     'name': 'Mr. Secretly Sid',
#     'screen_name': 'Sid_Amos_666',
#     'location': 'Jadebusen ',
#     'description': 'President of small dicks club, weißer alter Mann, seit 30 Jahren The Only One (TOO) treu, Miterfinder des Hashtag #Beiständer, FSK 63, My dark side @sidssecrets',
#     'url': 'https://t.co/T9zFekbqeq',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/T9zFekbqeq',
#         'expanded_url': 'http://sperrbezirk.wordpress.com/',
#         'display_url': 'sperrbezirk.wordpress.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 317,
#     'friends_count': 293,
#     'listed_count': 3,
#     'created_at': 'Mon May 21 18:14:57 +0000 2018',
#     'favourites_count': 13262,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 9836,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1216591361715195905/9fqpItRv_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1216591361715195905/9fqpItRv_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/998628224212094977/1595580027',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'und'},
#   {'created_at': 'Thu Aug 06 15:42:19 +0000 2020',
#    'id': 1291399211183988739,
#    'id_str': '1291399211183988739',
#    'text': '@Einzelfallinfos #MeToo',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MeToo', 'indices': [17, 23]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Einzelfallinfos',
#       'name': 'Einzelfallinfos',
#       'id': 838018569732501508,
#       'id_str': '838018569732501508',
#       'indices': [0, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1291322642906206216,
#    'in_reply_to_status_id_str': '1291322642906206216',
#    'in_reply_to_user_id': 838018569732501508,
#    'in_reply_to_user_id_str': '838018569732501508',
#    'in_reply_to_screen_name': 'Einzelfallinfos',
#    'user': {'id': 985187502,
# ...
#      {'text': 'Survivor', 'indices': [39, 48]},
#      {'text': 'Missouri', 'indices': [65, 74]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/PhyrtijSxj',
#       'expanded_url': 'https://www.kcur.org/news/2020-08-05/daisy-coleman-sexual-assault-survivor-in-high-profile-missouri-case-is-dead-at-23',
#       'display_url': 'kcur.org/news/2020-08-0…',
#       'indices': [104, 127]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1267082177658916864,
#     'id_str': '1267082177658916864',
#     'name': 'Rosemarie Vieth',
#     'screen_name': 'ViethRosemarie',
#     'location': '',
#     'description': 'We need to pay attention to the #science and ignore the ignorant. #maskswork if everyone wears a mask 😷.  PLEASE NO DM.  DM CLOSED.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 88,
#     'friends_count': 925,
#     'listed_count': 1,
#     'created_at': 'Sun May 31 13:15:23 +0000 2020',
#     'favourites_count': 4368,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 5497,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1267082706820706310/pAy5N31b_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1267082706820706310/pAy5N31b_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1267082177658916864/1596396996',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Aug 06 15:41:55 +0000 2020',
#    'id': 1291399109736374274,
#    'id_str': '1291399109736374274',
#    'text': 'RT @KaceyKells: #WritingCommunity: This is a definite recommend. One of the best (and most gut wrenching) books I have read in some time.…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'WritingCommunity',
#       'indices': [16, 33]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'KaceyKells',
#       'name': 'Kacey Kells',
#       'id': 1497738242,
#       'id_str': '1497738242',
#       'indices': [3, 14]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1497738242,
#     'id_str': '1497738242',
#     'name': 'Kacey Kells',
#     'screen_name': 'KaceyKells',
#     'location': 'London UK',
#     'description': "Author of 'KELLCEY'. From Victoria BC, I now live in London UK. I love fashion, books and feel concerned with women's rights #MeToo 🇨🇦🇬🇧",
#     'url': 'https://t.co/KQYqIU5EE5',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/KQYqIU5EE5',
#         'expanded_url': 'http://kaceykells.wixsite.com/kellcey',
#         'display_url': 'kaceykells.wixsite.com/kellcey',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 13119,
#     'friends_count': 8875,
#     'listed_count': 204,
#     'created_at': 'Mon Jun 10 08:34:29 +0000 2013',
#     'favourites_count': 33933,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 404360,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'FFFFFF',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme11/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme11/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/529233115131019264/qrzdJ1l3_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/529233115131019264/qrzdJ1l3_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1497738242/1560292018',
#     'profile_link_color': '7BB3DC',
#     'profile_sidebar_border_color': 'FFA400',
#     'profile_sidebar_fill_color': 'E32820',
#     'profile_text_color': '843AA9',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Jul 16 07:54:43 +0000 2020',
#     'id': 1283671389686439938,
#     'id_str': '1283671389686439938',
#     'text': '#WritingCommunity: This is a definite recommend. One of the best (and most gut wrenching) books I have read in some… https://t.co/qHpgh45MUI',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'WritingCommunity',
#        'indices': [0, 17]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/qHpgh45MUI',
#        'expanded_url': 'https://twitter.com/i/web/status/1283671389686439938',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1497738242,
#      'id_str': '1497738242',
#      'name': 'Kacey Kells',
#      'screen_name': 'KaceyKells',
#      'location': 'London UK',
#      'description': "Author of 'KELLCEY'. From Victoria BC, I now live in London UK. I love fashion, books and feel concerned with women's rights #MeToo 🇨🇦🇬🇧",
#      'url': 'https://t.co/KQYqIU5EE5',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KQYqIU5EE5',
#          'expanded_url': 'http://kaceykells.wixsite.com/kellcey',
#          'display_url': 'kaceykells.wixsite.com/kellcey',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 13119,
#      'friends_count': 8875,
#      'listed_count': 204,
#      'created_at': 'Mon Jun 10 08:34:29 +0000 2013',
#      'favourites_count': 33933,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 404360,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'FFFFFF',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme11/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme11/bg.gif',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/529233115131019264/qrzdJ1l3_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/529233115131019264/qrzdJ1l3_normal.png',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1497738242/1560292018',
#      'profile_link_color': '7BB3DC',
#      'profile_sidebar_border_color': 'FFA400',
#      'profile_sidebar_fill_color': 'E32820',
#      'profile_text_color': '843AA9',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 102,
#     'favorite_count': 60,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 102,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Aug 06 15:41:40 +0000 2020',
#    'id': 1291399045605404672,
#    'id_str': '1291399045605404672',
#    'text': 'RT @Citizen_Theresa: @lockwoodx3 biden is a pedophile and rapist. In this public record C-SPAN footage biden brazenly pinches this little g…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Citizen_Theresa',
#       'name': 'Citizen Theresa',
#       'id': 841330519283384320,
#       'id_str': '841330519283384320',
#       'indices': [3, 19]},
#      {'screen_name': 'lockwoodx3',
#       'name': 'lord Dokusei 🇹🇹',
#       'id': 1057384071691751425,
#       'id_str': '1057384071691751425',
#       'indices': [21, 32]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1057384071691751425,
#     'id_str': '1057384071691751425',
#     'name': 'lord Dokusei 🇹🇹',
#     'screen_name': 'lockwoodx3',
#     'location': '',
#     'description': "#NotMeUs #FreeJulianAssange\nEarth is the only home humanity knows, let's not destroy it. #BlackLivesMatter We need #M4A #GND\n\nNo arguments, ever. Strict no MAGA",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1206,
#     'friends_count': 621,
#     'listed_count': 4,
#     'created_at': 'Tue Oct 30 21:29:42 +0000 2018',
#     'favourites_count': 45982,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 45353,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1247426745248231424/1-i2VPti_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1247426745248231424/1-i2VPti_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1057384071691751425/1579056366',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Aug 06 15:26:49 +0000 2020',
#     'id': 1291395309994614784,
#     'id_str': '1291395309994614784',
#     'text': '@lockwoodx3 biden is a pedophile and rapist. In this public record C-SPAN footage biden brazenly pinches this littl… https://t.co/jr42puGYDV',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'lockwoodx3',
#        'name': 'lord Dokusei 🇹🇹',
#        'id': 1057384071691751425,
#        'id_str': '1057384071691751425',
#        'indices': [0, 11]}],
#      'urls': [{'url': 'https://t.co/jr42puGYDV',
#        'expanded_url': 'https://twitter.com/i/web/status/1291395309994614784',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': 1291393120618381312,
#     'in_reply_to_status_id_str': '1291393120618381312',
#     'in_reply_to_user_id': 1057384071691751425,
#     'in_reply_to_user_id_str': '1057384071691751425',
#     'in_reply_to_screen_name': 'lockwoodx3',
#     'user': {'id': 841330519283384320,
#      'id_str': '841330519283384320',
#      'name': 'Citizen Theresa',
#      'screen_name': 'Citizen_Theresa',
#      'location': 'Ahwatukee, AZ',
#      'description': 'Mom, wife, creative professional, advocate for integrity.',
#      'url': 'https://t.co/5MrqeuZmi8',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/5MrqeuZmi8',
#          'expanded_url': 'http://think-edge.com',
#          'display_url': 'think-edge.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 75,
#      'friends_count': 103,
#      'listed_count': 0,
#      'created_at': 'Mon Mar 13 16:50:01 +0000 2017',
#      'favourites_count': 3074,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 1476,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/950140391428255745/vPQmWUga_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/950140391428255745/vPQmWUga_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/841330519283384320/1489858553',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.092,
#   'max_id': 1291400054087938048,
#   'max_id_str': '1291400054087938048',
#   'next_results': '?max_id=1291399045605404671&q=%23metoo&include_entities=1',
#   'query': '%23metoo',
#   'refresh_url': '?since_id=1291400054087938048&q=%23metoo&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %% [markdown]
# **Step 2:  Adding Parameters to Your Query String**

# %% [markdown]
# Query strings basically have two parts:
#
#  - The `?` initiates the beginning of the API call, and basically says 'everything that follows this will encode something about the information that's going to get returned to you'.
#  - What follows that is are a bunch of symbols followed by `=` signs.  These are parameters.
#  - So when you make an api call to `'https://api.twitter.com/1.1/search/tweets.json?q=My%20Search%20Term`, the `q` is a paremeter.
#  - You can add multiple paremeters to a query string. They are separated by `&`. They dictate what kinds of results are returned.
#   - For example, a parameter you can use in Twitter's search API is `count`, which tells you how many results to return.  The default is 15, but you can return up to 100.  So if we wanted to search for tweets and return 50 results our query string would look like the following:
#     `https://api.twitter.com/1.1/search/tweets.json?q=My%20Search%20String&count=50`
#   - You can add as many of these parameters to your string as you'd like.  So for example, if we wanted to include parameters for `count` and `result_type`, we could do the following: `https://api.twitter.com/1.1/search/tweets.json?q=My%20Search%20String&count=50&result_type=mixed`
#
# To get the hang of this, try searching for tweets that mention the hashtag `#DeepLearning`, and return 75 results.

# %%
import requests
from requests_oauthlib import OAuth1
tweets_url = 'https://api.twitter.com/1.1/search/tweets.json'
tweets_data = requests.get(tweets_url, auth=auth).json()
tweets_url
# Out:
# 'https://api.twitter.com/1.1/search/tweets.json'

# %%
twitter_dl = 'https://api.twitter.com/1.1/search/tweets.json?q=%23deeplearning&count=75'
twitter_dl_data = requests.get(twitter_dl, auth=auth).json()

# %%
twitter_dl_data
# Out:
# {'statuses': [{'created_at': 'Thu Aug 06 15:50:17 +0000 2020',
#    'id': 1291401214190661635,
#    'id_str': '1291401214190661635',
#    'text': '9 #Chinese #skyscrapers priced over $250M sold in Q2.\n\nData: https://t.co/oifwsPDSl5\n\n#AlternativeData #DataScience… https://t.co/snGg2ef1MW',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'Chinese', 'indices': [2, 10]},
#      {'text': 'skyscrapers', 'indices': [11, 23]},
#      {'text': 'AlternativeData', 'indices': [86, 102]},
#      {'text': 'DataScience', 'indices': [103, 115]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/oifwsPDSl5',
#       'expanded_url': 'https://dfdnews.com/2020/07/30/china-bucks-apac-trend-japan-australia-multifamily-jump/',
#       'display_url': 'dfdnews.com/2020/07/30/chi…',
#       'indices': [61, 84]},
#      {'url': 'https://t.co/snGg2ef1MW',
#       'expanded_url': 'https://twitter.com/i/web/status/1291401214190661635',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'de', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1251316760722182146,
#     'id_str': '1251316760722182146',
#     'name': 'Derived From Data',
#     'screen_name': 'derivedfromdata',
#     'location': '',
#     'description': 'Derived from Data News (DFD News) aims to bring you news and research articles based on hard data. See the data and draw your own conclusions.',
#     'url': 'https://t.co/cyvPxFnO9P',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/cyvPxFnO9P',
#         'expanded_url': 'http://dfdnews.com',
#         'display_url': 'dfdnews.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 74,
#     'friends_count': 119,
#     'listed_count': 1,
#     'created_at': 'Sat Apr 18 01:09:08 +0000 2020',
#     'favourites_count': 3,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 319,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1277710688958525442/1KDd8mtL_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1277710688958525442/1KDd8mtL_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1251316760722182146/1593566509',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'de'},
#   {'created_at': 'Thu Aug 06 15:50:06 +0000 2020',
#    'id': 1291401167520641026,
#    'id_str': '1291401167520641026',
#    'text': 'RT @wil_bielert: RT @PinakiLaskar: What is your answer!\n\n#webdev #DevOps #programming #javascript #html #Linux #python #engeneering #Server…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'webdev', 'indices': [57, 64]},
#      {'text': 'DevOps', 'indices': [65, 72]},
#      {'text': 'programming', 'indices': [73, 85]},
#      {'text': 'javascript', 'indices': [86, 97]},
#      {'text': 'html', 'indices': [98, 103]},
#      {'text': 'Linux', 'indices': [104, 110]},
#      {'text': 'python', 'indices': [111, 118]},
#      {'text': 'engeneering', 'indices': [119, 131]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'wil_bielert',
#       'name': 'Wilhelm Bielert, PhD',
#       'id': 48707597,
#       'id_str': '48707597',
#       'indices': [3, 15]},
#      {'screen_name': 'PinakiLaskar',
#       'name': 'PINAKI',
#       'id': 1053697748321501184,
#       'id_str': '1053697748321501184',
#       'indices': [20, 33]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 909910016,
#     'id_str': '909910016',
#     'name': 'Rousseau Agnes',
#     'screen_name': 'RousseauAgnes',
#     'location': 'Paris',
#     'description': "Parisienne qui s'intéresse à l'étude interdisciplinaire des questions religieuses et aux revues de sciences sociales.",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 5070,
#     'friends_count': 3399,
#     'listed_count': 2487,
#     'created_at': 'Sun Oct 28 09:27:54 +0000 2012',
#     'favourites_count': 47321,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 490581,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/2774648802/f16c73baa5a6020d802b2291d145e963_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2774648802/f16c73baa5a6020d802b2291d145e963_normal.jpeg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/909910016/1399566851',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Aug 06 07:14:26 +0000 2020',
#     'id': 1291271396904009728,
#     'id_str': '1291271396904009728',
#     'text': 'RT @PinakiLaskar: What is your answer!\n\n#webdev #DevOps #programming #javascript #html #Linux #python #engeneering… https://t.co/nlJ6bxu5Mm',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'webdev', 'indices': [40, 47]},
#       {'text': 'DevOps', 'indices': [48, 55]},
#       {'text': 'programming', 'indices': [56, 68]},
#       {'text': 'javascript', 'indices': [69, 80]},
#       {'text': 'html', 'indices': [81, 86]},
#       {'text': 'Linux', 'indices': [87, 93]},
#       {'text': 'python', 'indices': [94, 101]},
#       {'text': 'engeneering', 'indices': [102, 114]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'PinakiLaskar',
#        'name': 'PINAKI',
#        'id': 1053697748321501184,
#        'id_str': '1053697748321501184',
#        'indices': [3, 16]}],
#      'urls': [{'url': 'https://t.co/nlJ6bxu5Mm',
#        'expanded_url': 'https://twitter.com/i/web/status/1291271396904009728',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 48707597,
#      'id_str': '48707597',
#      'name': 'Wilhelm Bielert, PhD',
#      'screen_name': 'wil_bielert',
#      'location': 'Quebec',
#      'description': 'Chief Digital Officer I distribute news I find personally interesting - contact me any time. #IIoT #AI #Digital',
#      'url': 'https://t.co/ZKVASRcmaF',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/ZKVASRcmaF',
#          'expanded_url': 'http://de.linkedin.com/in/wilbielert',
#          'display_url': 'de.linkedin.com/in/wilbielert',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 11709,
#      'friends_count': 8609,
#      'listed_count': 495,
#      'created_at': 'Fri Jun 19 13:40:19 +0000 2009',
#      'favourites_count': 462,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 142605,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1219671914144243713/lSmwfmDw_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1219671914144243713/lSmwfmDw_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/48707597/1579627491',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 13,
#     'favorite_count': 7,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 13,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Aug 06 15:50:03 +0000 2020',
#    'id': 1291401158385336320,
#    'id_str': '1291401158385336320',
#    'text': '9 Font Hacks for Instagram Stories You Should Know https://t.co/KPyrzrwvvd #socialmedia #digitalmarketing… https://t.co/8q20BHFgy0',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'socialmedia', 'indices': [75, 87]},
#      {'text': 'digitalmarketing', 'indices': [88, 105]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/KPyrzrwvvd',
#       'expanded_url': 'http://bit.ly/2BX0NMu',
#       'display_url': 'bit.ly/2BX0NMu',
#       'indices': [51, 74]},
#      {'url': 'https://t.co/8q20BHFgy0',
#       'expanded_url': 'https://twitter.com/i/web/status/1291401158385336320',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [107, 130]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3351431771,
#     'id_str': '3351431771',
#     'name': 'John Abraham',
#     'screen_name': 'iamjony94',
#     'location': 'Paris, France',
#     'description': 'Social Media Strategist, Certified Google Adwords & Analytics individual. Certified Inbound marketers. #socialmedia #digitalmarketing #SEO',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 13229,
#     'friends_count': 8600,
#     'listed_count': 422,
#     'created_at': 'Tue Jun 30 01:59:54 +0000 2015',
#     'favourites_count': 11346,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 55854,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1013396806909251584/rkNNxyN5_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1013396806909251584/rkNNxyN5_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3351431771/1482977460',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Aug 06 15:50:03 +0000 2020',
#    'id': 1291401156774842370,
#    'id_str': '1291401156774842370',
#    'text': 'A new AI language model generates poetry and prose \n\nREAD MORE: https://t.co/PfgZGNG1Tr\n\n#AI #DeepLearning… https://t.co/SRxIgvE1di',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'AI', 'indices': [89, 92]},
#      {'text': 'DeepLearning', 'indices': [93, 106]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/PfgZGNG1Tr',
#       'expanded_url': 'https://blog.iammarketingmedia.com/a-new-ai-language-model-generates-poetry-and-prose/?utm_campaign=twitter&utm_medium=twitter&utm_source=twitter',
#       'display_url': 'blog.iammarketingmedia.com/a-new-ai-langu…',
#       'indices': [64, 87]},
#      {'url': 'https://t.co/SRxIgvE1di',
#       'expanded_url': 'https://twitter.com/i/web/status/1291401156774842370',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [108, 131]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://www.blog.iammarketingmedia.com" rel="nofollow">IAMBLOG2TWITTER</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 226310002,
#     'id_str': '226310002',
#     'name': 'IAM Platform',
#     'screen_name': 'IAM__Network',
#     'location': 'Worldwide',
#     'description': 'Curation | Tools | Tips | Services\n\nIAM Platform powers IAM Network:\n\nGO: https://t.co/OJVc7LULBT\n\nBlog | Social | Podcast | Code Trove',
#     'url': 'https://t.co/T1FCdoOFoB',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/T1FCdoOFoB',
#         'expanded_url': 'https://www.iammarketingmedia.com',
#         'display_url': 'iammarketingmedia.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/OJVc7LULBT',
#         'expanded_url': 'http://bit.ly/2Ywsbg8',
#         'display_url': 'bit.ly/2Ywsbg8',
#         'indices': [74, 97]}]}},
#     'protected': False,
#     'followers_count': 17962,
#     'friends_count': 15107,
#     'listed_count': 3292,
#     'created_at': 'Mon Dec 13 21:24:29 +0000 2010',
#     'favourites_count': 65470,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 761947,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '94D487',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/701708113653669888/Nzm67hhC_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/701708113653669888/Nzm67hhC_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/226310002/1584072260',
#     'profile_link_color': '3366CC',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Aug 06 15:49:29 +0000 2020',
#    'id': 1291401015271579648,
#    'id_str': '1291401015271579648',
#    'text': 'RT @cuongcz: Millions lost jobs in pandemic and robots &amp; AI are replacing them https://t.co/xjEjPnwUsI #ai\xa0#ml\xa0#dl\xa0#artificialintelligence\xa0…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'ai', 'indices': [107, 110]},
#      {'text': 'ml', 'indices': [111, 114]},
#      {'text': 'dl', 'indices': [115, 118]},
#      {'text': 'artificialintelligence', 'indices': [119, 142]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'cuongcz',
#       'name': 'Cuong Nguyen Tien',
#       'id': 1309582843,
#       'id_str': '1309582843',
#       'indices': [3, 11]}],
#     'urls': [{'url': 'https://t.co/xjEjPnwUsI',
#       'expanded_url': 'https://ti.me/3fxlVJF',
#       'display_url': 'ti.me/3fxlVJF',
#       'indices': [83, 106]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://discussionexpress.com" rel="nofollow">Information Critical</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 16967457,
#     'id_str': '16967457',
#     'name': 'Don Robinson',
#     'screen_name': 'greentechdon',
#     'location': 'New Jersey',
#     'description': 'Branding goods and services for a #knowledge economy.\n#tech #innovation #fitness #data',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2745,
#     'friends_count': 563,
#     'listed_count': 79,
#     'created_at': 'Sat Oct 25 15:13:11 +0000 2008',
#     'favourites_count': 444,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 146031,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '9AE4E8',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1204063138938793986/GdXfiuuh_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1204063138938793986/GdXfiuuh_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16967457/1548345008',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'BDDCAD',
#     'profile_sidebar_fill_color': 'DDFFCC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Aug 06 15:48:32 +0000 2020',
#     'id': 1291400777110556672,
#     'id_str': '1291400777110556672',
#     'text': 'Millions lost jobs in pandemic and robots &amp; AI are replacing them https://t.co/xjEjPnwUsI #ai\xa0#ml\xa0#dl\xa0… https://t.co/MsXsi1MTFm',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'ai', 'indices': [94, 97]},
#       {'text': 'ml', 'indices': [98, 101]},
#       {'text': 'dl', 'indices': [102, 105]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/xjEjPnwUsI',
#        'expanded_url': 'https://ti.me/3fxlVJF',
#        'display_url': 'ti.me/3fxlVJF',
#        'indices': [70, 93]},
#       {'url': 'https://t.co/MsXsi1MTFm',
#        'expanded_url': 'https://twitter.com/i/web/status/1291400777110556672',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [108, 131]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1309582843,
#      'id_str': '1309582843',
#      'name': 'Cuong Nguyen Tien',
#      'screen_name': 'cuongcz',
#      'location': 'New York, NY',
#      'description': '#BigData | #Analytics | #Finance | #AI | #MachineLearning | #Startup | Ex-IBMer | 🇻🇳➡️🇨🇿➡️🇺🇸 | @LFC⚽️| tweets are my own',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 183,
#      'friends_count': 285,
#      'listed_count': 41,
#      'created_at': 'Thu Mar 28 06:04:46 +0000 2013',
#      'favourites_count': 150,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 592,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1276693300855144448/IZgMvj5H_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1276693300855144448/IZgMvj5H_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1309582843/1593231107',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Aug 06 15:49:15 +0000 2020',
#    'id': 1291400954005213184,
#    'id_str': '1291400954005213184',
#    'text': 'RT @TheInsaneApp: 🔥 Must Watch Ted Talks on Artificial Intelligence and Machine Learning\n\n#theinsaneapp #ML #AI\n#MachineLearning #BigData #…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'theinsaneapp', 'indices': [90, 103]},
#      {'text': 'ML', 'indices': [104, 107]},
#      {'text': 'AI', 'indices': [108, 111]},
#      {'text': 'MachineLearning', 'indices': [112, 128]},
#      {'text': 'BigData', 'indices': [129, 137]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'TheInsaneApp',
#       'name': 'Insane',
#       'id': 1064407014472744960,
#       'id_str': '1064407014472744960',
#       'indices': [3, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1028097331004989440,
#     'id_str': '1028097331004989440',
#     'name': 'Marsey... #EmergingTech #URFutureTech',
#     'screen_name': 'MFuturetech',
#     'location': '3rd rock from the Sun',
#     'description': 'Almost #DataScientist #ML #CV #RPA #DL #AI #NLP #MLOPS  #Greentech #Quantum #SCIENCE #Photonics #CyberSec  #sesquipedalianPhilomath #EGR2SRV #EcoFriendly.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 823,
#     'friends_count': 5023,
#     'listed_count': 25,
#     'created_at': 'Sat Aug 11 01:54:39 +0000 2018',
#     'favourites_count': 41851,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 26861,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1286078821561544704/vooJenFV_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1286078821561544704/vooJenFV_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1028097331004989440/1595459889',
#     'profile_link_color': 'E81C4F',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Aug 06 15:32:47 +0000 2020',
#     'id': 1291396810162880515,
#     'id_str': '1291396810162880515',
#     'text': '🔥 Must Watch Ted Talks on Artificial Intelligence and Machine Learning\n\n#theinsaneapp #ML #AI\n#MachineLearning… https://t.co/OkE1IuhIyo',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'theinsaneapp', 'indices': [72, 85]},
#       {'text': 'ML', 'indices': [86, 89]},
#       {'text': 'AI', 'indices': [90, 93]},
#       {'text': 'MachineLearning', 'indices': [94, 110]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/OkE1IuhIyo',
#        'expanded_url': 'https://twitter.com/i/web/status/1291396810162880515',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [112, 135]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1064407014472744960,
#      'id_str': '1064407014472744960',
#      'name': 'Insane',
#      'screen_name': 'TheInsaneApp',
#      'location': '',
#      'description': 'Feed your curiosity with Facts, Stories, and Summaries! Proudly followed by @MIT_CSAIL',
#      'url': 'https://t.co/UNantImjGP',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/UNantImjGP',
#          'expanded_url': 'http://tryinsane.page.link/TheInsaneApp',
#          'display_url': 'tryinsane.page.link/TheInsaneApp',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 8962,
#      'friends_count': 78,
#      'listed_count': 77,
#      'created_at': 'Mon Nov 19 06:36:22 +0000 2018',
#      'favourites_count': 6632,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 1605,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1211253505916166147/ge8jiGt7_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1211253505916166147/ge8jiGt7_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1064407014472744960/1585860005',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 21,
#     'favorite_count': 16,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 21,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Aug 06 15:49:14 +0000 2020',
#    'id': 1291400951941804035,
#    'id_str': '1291400951941804035',
#    'text': 'https://t.co/n4DP1SBuUc\n\nhttps://t.co/GGcH4UjEq9\n\nStreaming in 15 minutes! #MachineLearning #ArtificialIntelligence… https://t.co/GhZlvqP5XW',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'MachineLearning', 'indices': [75, 91]},
#      {'text': 'ArtificialIntelligence', 'indices': [92, 115]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/n4DP1SBuUc',
#       'expanded_url': 'https://www.youtube.com/watch?v=FQKX9E9NcZs',
#       'display_url': 'youtube.com/watch?v=FQKX9E…',
#       'indices': [0, 23]},
#      {'url': 'https://t.co/GGcH4UjEq9',
#       'expanded_url': 'https://www.twitch.tv/wasspen',
#       'display_url': 'twitch.tv/wasspen',
#       'indices': [25, 48]},
#      {'url': 'https://t.co/GhZlvqP5XW',
#       'expanded_url': 'https://twitter.com/i/web/status/1291400951941804035',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 122318079,
#     'id_str': '122318079',
#     'name': 'wasspDS',
#     'screen_name': 'wasspDS',
#     'location': '',
#     'description': 'Data Scientist, Security Researcher and a professional food eater.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 67,
#     'friends_count': 1302,
#     'listed_count': 0,
#     'created_at': 'Fri Mar 12 09:09:55 +0000 2010',
#     'favourites_count': 5,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 54,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1000042580179025920/j_ka3rCm_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1000042580179025920/j_ka3rCm_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Aug 06 15:49:08 +0000 2020',
#    'id': 1291400925341519875,
#    'id_str': '1291400925341519875',
#    'text': 'RT @SpirosMargaris: How #AI is Becoming Essential \n\nto #CyberStrategy \n\nhttps://t.co/AhVh8BX7eU #fintech #ArtificialIntelligence #MachineLe…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'AI', 'indices': [24, 27]},
#      {'text': 'CyberStrategy', 'indices': [55, 69]},
#      {'text': 'fintech', 'indices': [96, 104]},
#      {'text': 'ArtificialIntelligence', 'indices': [105, 128]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SpirosMargaris',
#       'name': 'Spiros Margaris',
#       'id': 2711212681,
#       'id_str': '2711212681',
#       'indices': [3, 18]}],
#     'urls': [{'url': 'https://t.co/AhVh8BX7eU',
#       'expanded_url': 'https://bit.ly/3gDiMtm',
#       'display_url': 'bit.ly/3gDiMtm',
#       'indices': [72, 95]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 560509154,
#     'id_str': '560509154',
#     'name': 'Francesca Ungaro',
#     'screen_name': 'franciungaro',
#     'location': 'Milano',
#     'description': 'Communication and Psychology Senior Consultant. https://t.co/5YTfnSOh6V #InLuce. Psicologa Clinica. Sorrido molto e non amo chi urla. In Partnership con @ORazionali',
#     'url': 'https://t.co/0ZBFuhUGVx',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/0ZBFuhUGVx',
#         'expanded_url': 'http://francescaungaro.it/',
#         'display_url': 'francescaungaro.it',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/5YTfnSOh6V',
#         'expanded_url': 'http://francescaungaro.it',
#         'display_url': 'francescaungaro.it',
#         'indices': [48, 71]}]}},
#     'protected': False,
#     'followers_count': 26491,
#     'friends_count': 10006,
#     'listed_count': 2128,
#     'created_at': 'Sun Apr 22 18:49:34 +0000 2012',
#     'favourites_count': 167058,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 166950,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'DBE9ED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme17/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme17/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1276465882089295872/ugxMi7It_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1276465882089295872/ugxMi7It_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/560509154/1497885905',
#     'profile_link_color': 'CC3366',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'E6F6F9',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Aug 06 02:16:03 +0000 2020',
#     'id': 1291196306271211523,
#     'id_str': '1291196306271211523',
#     'text': 'How #AI is Becoming Essential \n\nto #CyberStrategy \n\nhttps://t.co/AhVh8BX7eU #fintech #ArtificialIntelligence… https://t.co/ZEpOtgZW6z',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'AI', 'indices': [4, 7]},
#       {'text': 'CyberStrategy', 'indices': [35, 49]},
#       {'text': 'fintech', 'indices': [76, 84]},
#       {'text': 'ArtificialIntelligence', 'indices': [85, 108]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/AhVh8BX7eU',
#        'expanded_url': 'https://bit.ly/3gDiMtm',
#        'display_url': 'bit.ly/3gDiMtm',
#        'indices': [52, 75]},
#       {'url': 'https://t.co/ZEpOtgZW6z',
#        'expanded_url': 'https://twitter.com/i/web/status/1291196306271211523',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [110, 133]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 2711212681,
#      'id_str': '2711212681',
#      'name': 'Spiros Margaris',
#      'screen_name': 'SpirosMargaris',
#      'location': 'All Over the World',
#      'description': '#VC #Futurist | @wefoxHQ @SparkLabsGlobal @ai_mediastalker @canopyrent @yieldgrowth @F10_accelerator | No.1 #Fintech Influencer @Onalytica #AI | @TEDx',
#      'url': 'https://t.co/PeTBLwijX6',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/PeTBLwijX6',
#          'expanded_url': 'http://www.MargarisVentures.com',
#          'display_url': 'MargarisVentures.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 101235,
#      'friends_count': 14614,
#      'listed_count': 5511,
#      'created_at': 'Wed Aug 06 05:20:16 +0000 2014',
#      'favourites_count': 168800,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 194826,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '3B94D9',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1080518156932825089/Elhx7SXw_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1080518156932825089/Elhx7SXw_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2711212681/1596036150',
#      'profile_link_color': '1C2841',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 22,
#     'favorite_count': 26,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 22,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Aug 06 15:49:00 +0000 2020',
#    'id': 1291400891141107715,
#    'id_str': '1291400891141107715',
#    'text': 'RT @wil_bielert: RT @PinakiLaskar: What is your answer!\n\n#webdev #DevOps #programming #javascript #html #Linux #python #engeneering #Server…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'webdev', 'indices': [57, 64]},
#      {'text': 'DevOps', 'indices': [65, 72]},
#      {'text': 'programming', 'indices': [73, 85]},
#      {'text': 'javascript', 'indices': [86, 97]},
#      {'text': 'html', 'indices': [98, 103]},
#      {'text': 'Linux', 'indices': [104, 110]},
#      {'text': 'python', 'indices': [111, 118]},
#      {'text': 'engeneering', 'indices': [119, 131]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'wil_bielert',
#       'name': 'Wilhelm Bielert, PhD',
#       'id': 48707597,
#       'id_str': '48707597',
#       'indices': [3, 15]},
#      {'screen_name': 'PinakiLaskar',
#       'name': 'PINAKI',
#       'id': 1053697748321501184,
#       'id_str': '1053697748321501184',
#       'indices': [20, 33]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://github.com/vlipatdev" rel="nofollow">Code Newbie Server</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1267052345822572545,
#     'id_str': '1267052345822572545',
#     'name': 'Code Newbie Bot',
#     'screen_name': '_codenewbiebot',
#     'location': '',
#     'description': 'Beep boop. I am a bot created by https://t.co/i0ytpsE5Sj to support code newbies.',
#     'url': None,
#     'entities': {'description': {'urls': [{'url': 'https://t.co/i0ytpsE5Sj',
#         'expanded_url': 'http://github.com/vlipatdev',
#         'display_url': 'github.com/vlipatdev',
#         'indices': [33, 56]}]}},
#     'protected': False,
#     'followers_count': 418,
#     'friends_count': 9,
#     'listed_count': 15,
#     'created_at': 'Sun May 31 11:17:02 +0000 2020',
#     'favourites_count': 12,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 39366,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1270342281430777858/4ExBd_dP_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1270342281430777858/4ExBd_dP_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Aug 06 07:14:26 +0000 2020',
#     'id': 1291271396904009728,
#     'id_str': '1291271396904009728',
#     'text': 'RT @PinakiLaskar: What is your answer!\n\n#webdev #DevOps #programming #javascript #html #Linux #python #engeneering… https://t.co/nlJ6bxu5Mm',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'webdev', 'indices': [40, 47]},
#       {'text': 'DevOps', 'indices': [48, 55]},
#       {'text': 'programming', 'indices': [56, 68]},
#       {'text': 'javascript', 'indices': [69, 80]},
#       {'text': 'html', 'indices': [81, 86]},
#       {'text': 'Linux', 'indices': [87, 93]},
#       {'text': 'python', 'indices': [94, 101]},
#       {'text': 'engeneering', 'indices': [102, 114]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'PinakiLaskar',
#        'name': 'PINAKI',
#        'id': 1053697748321501184,
#        'id_str': '1053697748321501184',
#        'indices': [3, 16]}],
#      'urls': [{'url': 'https://t.co/nlJ6bxu5Mm',
#        'expanded_url': 'https://twitter.com/i/web/status/1291271396904009728',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 48707597,
#      'id_str': '48707597',
#      'name': 'Wilhelm Bielert, PhD',
#      'screen_name': 'wil_bielert',
#      'location': 'Quebec',
#      'description': 'Chief Digital Officer I distribute news I find personally interesting - contact me any time. #IIoT #AI #Digital',
#      'url': 'https://t.co/ZKVASRcmaF',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/ZKVASRcmaF',
#          'expanded_url': 'http://de.linkedin.com/in/wilbielert',
#          'display_url': 'de.linkedin.com/in/wilbielert',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 11709,
#      'friends_count': 8609,
#      'listed_count': 495,
#      'created_at': 'Fri Jun 19 13:40:19 +0000 2009',
#      'favourites_count': 462,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 142605,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1219671914144243713/lSmwfmDw_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1219671914144243713/lSmwfmDw_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/48707597/1579627491',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
# ...
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [115, 138]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://www.bitechwatch.com" rel="nofollow">SocialyAnxious</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 22631958,
#      'id_str': '22631958',
#      'name': 'Chuck Russell',
#      'screen_name': 'cichuck',
#      'location': 'Harrisburg, PA',
#      'description': 'Founder Collective Intelligence  #TheFutureOfWork #BMGI #TheBigShift #ai #datascience #blockchain #IOT',
#      'url': 'https://t.co/Fz05cosWBh',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/Fz05cosWBh',
#          'expanded_url': 'http://www.collectiveintelligence.com',
#          'display_url': 'collectiveintelligence.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 9364,
#      'friends_count': 7675,
#      'listed_count': 605,
#      'created_at': 'Tue Mar 03 15:05:32 +0000 2009',
#      'favourites_count': 4504,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 62468,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '709397',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme6/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme6/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1071464844547760128/xMYEz39W_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1071464844547760128/xMYEz39W_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/22631958/1355679181',
#      'profile_link_color': 'FF3300',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'A0C5C7',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Aug 06 15:39:08 +0000 2020',
#    'id': 1291398411451858951,
#    'id_str': '1291398411451858951',
#    'text': 'RT @TheInsaneApp: 🔥 Must Watch Ted Talks on Artificial Intelligence and Machine Learning\n\n#theinsaneapp #ML #AI\n#MachineLearning #BigData #…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'theinsaneapp', 'indices': [90, 103]},
#      {'text': 'ML', 'indices': [104, 107]},
#      {'text': 'AI', 'indices': [108, 111]},
#      {'text': 'MachineLearning', 'indices': [112, 128]},
#      {'text': 'BigData', 'indices': [129, 137]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'TheInsaneApp',
#       'name': 'Insane',
#       'id': 1064407014472744960,
#       'id_str': '1064407014472744960',
#       'indices': [3, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://avcourt.github.io/tiny-cluster" rel="nofollow">dd-bot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1152052858721918977,
#     'id_str': '1152052858721918977',
#     'name': 'LinuxDreams',
#     'screen_name': 'LinuxDreams',
#     'location': 'digitalocean',
#     'description': 'A bot that retweets #linux. Written by @avcourt.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1807,
#     'friends_count': 1,
#     'listed_count': 63,
#     'created_at': 'Fri Jul 19 03:09:40 +0000 2019',
#     'favourites_count': 27,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 154465,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1153139246024286213/VIdgxJuX_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1153139246024286213/VIdgxJuX_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1152052858721918977/1574484974',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Aug 06 15:32:47 +0000 2020',
#     'id': 1291396810162880515,
#     'id_str': '1291396810162880515',
#     'text': '🔥 Must Watch Ted Talks on Artificial Intelligence and Machine Learning\n\n#theinsaneapp #ML #AI\n#MachineLearning… https://t.co/OkE1IuhIyo',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'theinsaneapp', 'indices': [72, 85]},
#       {'text': 'ML', 'indices': [86, 89]},
#       {'text': 'AI', 'indices': [90, 93]},
#       {'text': 'MachineLearning', 'indices': [94, 110]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/OkE1IuhIyo',
#        'expanded_url': 'https://twitter.com/i/web/status/1291396810162880515',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [112, 135]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1064407014472744960,
#      'id_str': '1064407014472744960',
#      'name': 'Insane',
#      'screen_name': 'TheInsaneApp',
#      'location': '',
#      'description': 'Feed your curiosity with Facts, Stories, and Summaries! Proudly followed by @MIT_CSAIL',
#      'url': 'https://t.co/UNantImjGP',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/UNantImjGP',
#          'expanded_url': 'http://tryinsane.page.link/TheInsaneApp',
#          'display_url': 'tryinsane.page.link/TheInsaneApp',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 8962,
#      'friends_count': 78,
#      'listed_count': 77,
#      'created_at': 'Mon Nov 19 06:36:22 +0000 2018',
#      'favourites_count': 6632,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 1605,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1211253505916166147/ge8jiGt7_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1211253505916166147/ge8jiGt7_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1064407014472744960/1585860005',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 21,
#     'favorite_count': 16,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 21,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Aug 06 15:39:06 +0000 2020',
#    'id': 1291398401674768389,
#    'id_str': '1291398401674768389',
#    'text': 'RT @Analytics_699: New " Image search" algorithm finds the closest match by a particular artist or culture ▶️\n#ArtificialInteligence #DeepL…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'ArtificialInteligence',
#       'indices': [110, 132]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Analytics_699',
#       'name': 'Maac',
#       'id': 1155470031225884675,
#       'id_str': '1155470031225884675',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1155470031225884675,
#     'id_str': '1155470031225884675',
#     'name': 'Maac',
#     'screen_name': 'Analytics_699',
#     'location': '',
#     'description': 'Consulting - Health Tech - Futurism | @aboutKP | \n#AI #BI #BigData #DataScience #IoT #Robotics #AR #VR | Travel-Poetry-Art-Metal',
#     'url': 'https://t.co/6laz24KCCn',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/6laz24KCCn',
#         'expanded_url': 'https://thrive.kaiserpermanente.org/',
#         'display_url': 'thrive.kaiserpermanente.org',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2115,
#     'friends_count': 2171,
#     'listed_count': 11,
#     'created_at': 'Sun Jul 28 13:28:17 +0000 2019',
#     'favourites_count': 4706,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1538,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1270928144229437440/Ie08vEBd_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1270928144229437440/Ie08vEBd_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1155470031225884675/1595503868',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Aug 06 13:27:22 +0000 2020',
#     'id': 1291365248100732929,
#     'id_str': '1291365248100732929',
#     'text': 'New " Image search" algorithm finds the closest match by a particular artist or culture ▶️\n#ArtificialInteligence… https://t.co/sVX9UsJ6Io',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'ArtificialInteligence',
#        'indices': [91, 113]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/sVX9UsJ6Io',
#        'expanded_url': 'https://twitter.com/i/web/status/1291365248100732929',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [115, 138]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1155470031225884675,
#      'id_str': '1155470031225884675',
#      'name': 'Maac',
#      'screen_name': 'Analytics_699',
#      'location': '',
#      'description': 'Consulting - Health Tech - Futurism | @aboutKP | \n#AI #BI #BigData #DataScience #IoT #Robotics #AR #VR | Travel-Poetry-Art-Metal',
#      'url': 'https://t.co/6laz24KCCn',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/6laz24KCCn',
#          'expanded_url': 'https://thrive.kaiserpermanente.org/',
#          'display_url': 'thrive.kaiserpermanente.org',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2115,
#      'friends_count': 2171,
#      'listed_count': 11,
#      'created_at': 'Sun Jul 28 13:28:17 +0000 2019',
#      'favourites_count': 4706,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 1538,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1270928144229437440/Ie08vEBd_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1270928144229437440/Ie08vEBd_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1155470031225884675/1595503868',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 8,
#     'favorite_count': 5,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 8,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.161,
#   'max_id': 1291401214190661635,
#   'max_id_str': '1291401214190661635',
#   'next_results': '?max_id=1291398401674768388&q=%23deeplearning&count=75&include_entities=1',
#   'query': '%23deeplearning',
#   'refresh_url': '?since_id=1291401214190661635&q=%23deeplearning&include_entities=1',
#   'count': 75,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %% [markdown]
# Try adding a second parameter.  You can find the list here:  https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets

# %%
twitter_dlp2 = 'https://api.twitter.com/1.1/search/tweets.json?q=%23deeplearning&count=75&until=2020-03-14'
twitter_dl_datap2 = requests.get(twitter_dlp2, auth=auth).json()

# %%
twitter_dl_datap2
# Out:
# {'statuses': [],
#  'search_metadata': {'completed_in': 0.004,
#   'max_id': 1291402389969960960,
#   'max_id_str': '1291402389969960960',
#   'query': '%23deeplearning+until%3A2020-03-14',
#   'refresh_url': '?since_id=1291402389969960960&q=%23deeplearning%20until%3A2020-03-14&include_entities=1',
#   'count': 75,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %% [markdown]
# ## Section 3: Searching Users

# %% [markdown]
# The last section of the API you'll need to get the hang of before you're let loose is the users API, which allows you to search for users and get their followers, friends, etc, as opposed to tweets which fit a particular criteria.  This part is pretty similar to the advanced lab in class 3, so if you saw how that worked then you shouldn't need much instruction.
#
# But if you're seeing this with fresh eyes, you'll want to spend 15-20 minutes to make sure you understand this part.
#
# Official documentation can be found here:  https://developer.twitter.com/en/docs/accounts-and-users/follow-search-get-users/overview
#
# So, as an example, if you want to get a list of someone's followers, you use the base url `https://api.twitter.com/1.1/followers/list.json` and then enter your query string to get a list of that person's followers.
#
# List of parameters to use can be found here:  https://developer.twitter.com/en/docs/accounts-and-users/follow-search-get-users/api-reference/get-followers-list
#
# One possible parameter to use is `screen_name`, so if you wanted to get a list of someone's followers based on their screen name (the handle that begins with an @), then you would set up your API call to look something like:
#
# `https://api.twitter.com/1.1/followers/list.json?screen_name=persons_screenname`
#
# Note that you exclude the `@`.
#
# **Your turn:** Pull in the list of General Assembly's followers.  General Assembly's handle is `@GA`.
#
# Note that this won't return the whole list of GA's users.  If you want to do that you have to use cursoring:  https://developer.twitter.com/en/docs/basics/cursoring.  This is the topic of your bonus assignment.

# %%
import requests
from requests_oauthlib import OAuth1
tweets_user = 'https://api.twitter.com/1.1/followers/list.json'
tweets_userdata = requests.get(tweets_user, auth=auth).json()

# %%
twitter_ga = 'https://api.twitter.com/1.1/followers/list.json?screen_name=ga'
twitter_gafollowers = requests.get(twitter_ga, auth=auth).json()

# %%
twitter_gafollowers
# Out:
# {'users': [{'id': 2751490248,
#    'id_str': '2751490248',
#    'name': 'Eng. Abdurrahman Jama 🇸🇴',
#    'screen_name': 'abdurrahmaan111',
#    'location': 'Somalia',
#    'description': '☆Agricultural Engineer , researcher, intrapreneur, social activist.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': True,
#    'followers_count': 45,
#    'friends_count': 1908,
#    'listed_count': 0,
#    'created_at': 'Thu Aug 21 06:51:13 +0000 2014',
#    'favourites_count': 63,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 32,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1191790763283275776/GuxgGXZp_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1191790763283275776/GuxgGXZp_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2751490248/1525771490',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1189836659992485888,
#    'id_str': '1189836659992485888',
#    'name': 'lauraa_susii',
#    'screen_name': 'LauraaSusii',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 4,
#    'friends_count': 105,
#    'listed_count': 0,
#    'created_at': 'Thu Oct 31 09:29:11 +0000 2019',
#    'favourites_count': 3113,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 0,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#    'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': True,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 63037812,
#    'id_str': '63037812',
#    'name': 'Paulo Guerra',
#    'screen_name': 'paulo_guerra_f',
#    'location': 'Quito, Ecuador',
#    'description': 'Interaction design. Creative coding. Full stack software and hardware development. @UDLAQuito Multimedia and Interactivity Professor',
#    'url': 'https://t.co/LDZYTYe2J0',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/LDZYTYe2J0',
#        'expanded_url': 'http://www.pauloguerraf.com',
#        'display_url': 'pauloguerraf.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 285,
#    'friends_count': 1773,
#    'listed_count': 14,
#    'created_at': 'Wed Aug 05 04:57:14 +0000 2009',
#    'favourites_count': 4546,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 1066,
#    'lang': None,
#    'status': {'created_at': 'Sat Aug 01 22:10:42 +0000 2020',
#     'id': 1289685010497146885,
#     'id_str': '1289685010497146885',
#     'text': 'RT @EstebanOrtizMD: Me encanta tuiter 🙌 https://t.co/Su1kYFdFBQ',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'EstebanOrtizMD',
#        'name': 'Esteban Ortiz',
#        'id': 210077250,
#        'id_str': '210077250',
#        'indices': [3, 18]}],
#      'urls': [],
#      'media': [{'id': 1289614071080333315,
#        'id_str': '1289614071080333315',
#        'indices': [40, 63],
#        'media_url': 'http://pbs.twimg.com/media/EeWhKjwWsAMlOGQ.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EeWhKjwWsAMlOGQ.jpg',
#        'url': 'https://t.co/Su1kYFdFBQ',
#        'display_url': 'pic.twitter.com/Su1kYFdFBQ',
#        'expanded_url': 'https://twitter.com/EstebanOrtizMD/status/1289614081356226560/photo/1',
#        'type': 'photo',
#        'sizes': {'medium': {'w': 640, 'h': 400, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 640, 'h': 400, 'resize': 'fit'},
#         'large': {'w': 640, 'h': 400, 'resize': 'fit'}},
#        'source_status_id': 1289614081356226560,
#        'source_status_id_str': '1289614081356226560',
#        'source_user_id': 210077250,
#        'source_user_id_str': '210077250'}]},
#     'extended_entities': {'media': [{'id': 1289614071080333315,
#        'id_str': '1289614071080333315',
#        'indices': [40, 63],
#        'media_url': 'http://pbs.twimg.com/media/EeWhKjwWsAMlOGQ.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EeWhKjwWsAMlOGQ.jpg',
#        'url': 'https://t.co/Su1kYFdFBQ',
#        'display_url': 'pic.twitter.com/Su1kYFdFBQ',
#        'expanded_url': 'https://twitter.com/EstebanOrtizMD/status/1289614081356226560/photo/1',
#        'type': 'photo',
#        'sizes': {'medium': {'w': 640, 'h': 400, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 640, 'h': 400, 'resize': 'fit'},
#         'large': {'w': 640, 'h': 400, 'resize': 'fit'}},
#        'source_status_id': 1289614081356226560,
#        'source_status_id_str': '1289614081356226560',
#        'source_user_id': 210077250,
#        'source_user_id_str': '210077250'}]},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Sat Aug 01 17:28:51 +0000 2020',
#      'id': 1289614081356226560,
#      'id_str': '1289614081356226560',
#      'text': 'Me encanta tuiter 🙌 https://t.co/Su1kYFdFBQ',
#      'truncated': False,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [],
#       'media': [{'id': 1289614071080333315,
#         'id_str': '1289614071080333315',
#         'indices': [20, 43],
#         'media_url': 'http://pbs.twimg.com/media/EeWhKjwWsAMlOGQ.jpg',
#         'media_url_https': 'https://pbs.twimg.com/media/EeWhKjwWsAMlOGQ.jpg',
#         'url': 'https://t.co/Su1kYFdFBQ',
#         'display_url': 'pic.twitter.com/Su1kYFdFBQ',
#         'expanded_url': 'https://twitter.com/EstebanOrtizMD/status/1289614081356226560/photo/1',
#         'type': 'photo',
#         'sizes': {'medium': {'w': 640, 'h': 400, 'resize': 'fit'},
#          'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#          'small': {'w': 640, 'h': 400, 'resize': 'fit'},
#          'large': {'w': 640, 'h': 400, 'resize': 'fit'}}}]},
#      'extended_entities': {'media': [{'id': 1289614071080333315,
#         'id_str': '1289614071080333315',
#         'indices': [20, 43],
#         'media_url': 'http://pbs.twimg.com/media/EeWhKjwWsAMlOGQ.jpg',
#         'media_url_https': 'https://pbs.twimg.com/media/EeWhKjwWsAMlOGQ.jpg',
#         'url': 'https://t.co/Su1kYFdFBQ',
#         'display_url': 'pic.twitter.com/Su1kYFdFBQ',
#         'expanded_url': 'https://twitter.com/EstebanOrtizMD/status/1289614081356226560/photo/1',
#         'type': 'photo',
#         'sizes': {'medium': {'w': 640, 'h': 400, 'resize': 'fit'},
#          'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#          'small': {'w': 640, 'h': 400, 'resize': 'fit'},
#          'large': {'w': 640, 'h': 400, 'resize': 'fit'}}}]},
#      'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': {'id': '0177bc687a9ac697',
#       'url': 'https://api.twitter.com/1.1/geo/id/0177bc687a9ac697.json',
#       'place_type': 'city',
#       'name': 'Quito',
#       'full_name': 'Quito, Ecuador',
#       'country_code': 'EC',
#       'country': 'Ecuador',
#       'contained_within': [],
#       'bounding_box': {'type': 'Polygon',
#        'coordinates': [[[-78.948465999276, -0.588618000469648],
#          [-78.1648970044175, -0.588618000469648],
#          [-78.1648970044175, 0.255476999458879],
#          [-78.948465999276, 0.255476999458879]]]},
#       'attributes': {}},
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 279,
#      'favorite_count': 1020,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'es'},
#     'is_quote_status': False,
#     'retweet_count': 279,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'es'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/721070653684768769/Flp8pbxe_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/721070653684768769/Flp8pbxe_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 126173172,
#    'id_str': '126173172',
#    'name': 'Tolu Arogunmati',
#    'screen_name': 'aeromati',
#    'location': 'Shalom',
#    'description': 'ENTP. Valar Dohaeris. "you can either, run from it or learn from it" - Rafiki',
#    'url': 'https://t.co/RRtRseK5iQ',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/RRtRseK5iQ',
#        'expanded_url': 'http://toluarogunmati.com/',
#        'display_url': 'toluarogunmati.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 663,
#    'friends_count': 516,
#    'listed_count': 4,
#    'created_at': 'Thu Mar 25 01:50:36 +0000 2010',
#    'favourites_count': 603,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 38189,
#    'lang': None,
#    'status': {'created_at': 'Thu Aug 06 03:46:41 +0000 2020',
#     'id': 1291219114002911232,
#     'id_str': '1291219114002911232',
#     'text': '@Rezi_la_reina It’s not a bad watch in the end. Half the time I was confused by the plot direction.\nIt’s good to wa… https://t.co/m3LyS2r8Ho',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'Rezi_la_reina',
#        'name': 'Zee Odogwu',
#        'id': 177356933,
#        'id_str': '177356933',
#        'indices': [0, 14]}],
#      'urls': [{'url': 'https://t.co/m3LyS2r8Ho',
#        'expanded_url': 'https://twitter.com/i/web/status/1291219114002911232',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': 1291210485006774272,
#     'in_reply_to_status_id_str': '1291210485006774272',
#     'in_reply_to_user_id': 177356933,
#     'in_reply_to_user_id_str': '177356933',
#     'in_reply_to_screen_name': 'Rezi_la_reina',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1211222663416483840/-jQeMBTB_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1211222663416483840/-jQeMBTB_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/126173172/1577613965',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': '4DCC33',
#    'profile_text_color': '282B15',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 759396570748116992,
#    'id_str': '759396570748116992',
#    'name': 'PATRICIA RODRIGUES',
#    'screen_name': 'patriciacr0994',
#    'location': 'Mumbai, India',
#    'description': 'Deep Learning Engineer',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 8,
#    'friends_count': 252,
#    'listed_count': 0,
#    'created_at': 'Sat Jul 30 14:33:46 +0000 2016',
#    'favourites_count': 54,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 3,
#    'lang': None,
#    'status': {'created_at': 'Mon Apr 27 20:28:59 +0000 2020',
#     'id': 1254870177432256512,
#     'id_str': '1254870177432256512',
#     'text': 'After seeing trump handle coronavirus\n\nMexico : I will pay, just build the wall.',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1252979144364703744/QifR8Ko7_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1252979144364703744/QifR8Ko7_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/759396570748116992/1587568582',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1170750817,
#    'id_str': '1170750817',
#    'name': 'Mobile Patterns',
#    'screen_name': 'mobile_patterns',
#    'location': 'Orlando, FL',
#    'description': 'Get inspiration from the latest collection of UX & UI Designs | Practical Advice on Mobile UX | Made with love for designers by designers',
#    'url': 'http://t.co/oJ6CDvVpTg',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/oJ6CDvVpTg',
#        'expanded_url': 'http://mobile-patterns.com',
#        'display_url': 'mobile-patterns.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 565,
#    'friends_count': 79,
#    'listed_count': 14,
#    'created_at': 'Tue Feb 12 03:13:57 +0000 2013',
#    'favourites_count': 406,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 676,
#    'lang': None,
#    'status': {'created_at': 'Thu Aug 06 13:00:27 +0000 2020',
#     'id': 1291358475797303297,
#     'id_str': '1291358475797303297',
#     'text': 'Sending a parcel with AR\n\n#Design by @damianbilski 🎨\n\nTap ♡ 🔁 &amp; 💬 comment on what you think of this design.📲… https://t.co/83lhRTmF20',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Design', 'indices': [26, 33]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'damianbilski',
#        'name': 'Damian Bilski',
#        'id': 118675565,
#        'id_str': '118675565',
#        'indices': [37, 50]}],
#      'urls': [{'url': 'https://t.co/83lhRTmF20',
#        'expanded_url': 'https://twitter.com/i/web/status/1291358475797303297',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [114, 137]}]},
#     'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '292929',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/766037096712835072/gyuOOCeQ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/766037096712835072/gyuOOCeQ_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1170750817/1472596258',
#    'profile_link_color': 'ABB8C2',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1286567359998648321,
#    'id_str': '1286567359998648321',
#    'name': 'North Field',
#    'screen_name': 'fieldnorth1',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 3,
#    'friends_count': 18,
#    'listed_count': 0,
#    'created_at': 'Fri Jul 24 07:42:40 +0000 2020',
#    'favourites_count': 0,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 0,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1286629872782123008/0j73KoFQ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1286629872782123008/0j73KoFQ_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 27844105,
#    'id_str': '27844105',
#    'name': 'BB',
#    'screen_name': 'Rheinhart',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': True,
#    'followers_count': 49,
#    'friends_count': 394,
#    'listed_count': 2,
#    'created_at': 'Tue Mar 31 09:55:06 +0000 2009',
#    'favourites_count': 31,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 154,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '352726',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme5/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme5/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/700486370926526465/dTdJUMhX_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/700486370926526465/dTdJUMhX_normal.jpg',
#    'profile_link_color': 'D02B55',
#    'profile_sidebar_border_color': '829D5E',
#    'profile_sidebar_fill_color': '99CC33',
#    'profile_text_color': '3E4415',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 493267967,
#    'id_str': '493267967',
#    'name': 'Cristina Bardas',
#    'screen_name': 'CrissAdriana',
#    'location': 'Edinburgh, Scotland',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 33,
#    'friends_count': 161,
#    'listed_count': 1,
#    'created_at': 'Wed Feb 15 16:32:29 +0000 2012',
#    'favourites_count': 136,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 16,
#    'lang': None,
#    'status': {'created_at': 'Thu Jun 25 17:04:20 +0000 2020',
#     'id': 1276199560482783234,
#     'id_str': '1276199560482783234',
#     'text': '@ThreeUKSupport Support team is not happy to help because they keep telling me what should happen (how a contract i… https://t.co/OFYWtvZStO',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'ThreeUKSupport',
#        'name': 'ThreeUKSupport',
#        'id': 361268597,
#        'id_str': '361268597',
#        'indices': [0, 15]}],
#      'urls': [{'url': 'https://t.co/OFYWtvZStO',
#        'expanded_url': 'https://twitter.com/i/web/status/1276199560482783234',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': 1276186383560986629,
#     'in_reply_to_status_id_str': '1276186383560986629',
#     'in_reply_to_user_id': 361268597,
#     'in_reply_to_user_id_str': '361268597',
#     'in_reply_to_screen_name': 'ThreeUKSupport',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/698964343094976513/4tVtGCYh_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/698964343094976513/4tVtGCYh_normal.jpg',
#    'profile_link_color': '3B94D9',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1290901125139505152,
#    'id_str': '1290901125139505152',
#    'name': 'Anant Awasthy',
#    'screen_name': 'AwasthyAnant',
#    'location': '',
#    'description': 'Web development and data science fan',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 4,
#    'friends_count': 34,
#    'listed_count': 0,
#    'created_at': 'Wed Aug 05 06:43:20 +0000 2020',
#    'favourites_count': 7,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 3,
#    'lang': None,
#    'status': {'created_at': 'Wed Aug 05 18:17:23 +0000 2020',
#     'id': 1291075847927955456,
#     'id_str': '1291075847927955456',
#     'text': "RT @traversymedia: Who are some smaller programming YouTubers that you like that are high quality? \n\nIt doesn't just have to be tutorials a…",
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'traversymedia',
#        'name': 'Brad Traversy',
#        'id': 870038005,
#        'id_str': '870038005',
#        'indices': [3, 17]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Tue Aug 04 19:46:17 +0000 2020',
#      'id': 1290735833113337857,
#      'id_str': '1290735833113337857',
#      'text': "Who are some smaller programming YouTubers that you like that are high quality? \n\nIt doesn't just have to be tutori… https://t.co/RRiXe0sXhm",
#      'truncated': True,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/RRiXe0sXhm',
#         'expanded_url': 'https://twitter.com/i/web/status/1290735833113337857',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [117, 140]}]},
#      'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 136,
#      'favorite_count': 1132,
#      'favorited': False,
#      'retweeted': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 136,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1290901385895002114/FBlLf1CY_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1290901385895002114/FBlLf1CY_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1291308408545501185,
#    'id_str': '1291308408545501185',
#    'name': 'Marleen Johnsrud',
#    'screen_name': 'JohnsrudMarleen',
#    'location': '',
#    'description': 'Food evangelist. Coffee fanatic. Unapologetic organizer. Web specialist. Tv junkie. Extreme travel aficionado.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 0,
#    'friends_count': 8,
#    'listed_count': 0,
#    'created_at': 'Thu Aug 06 09:41:40 +0000 2020',
#    'favourites_count': 0,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 0,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1291308637713965058/TR7ujTbl_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1291308637713965058/TR7ujTbl_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1331884183,
#    'id_str': '1331884183',
#    'name': 'Nicols Xquisite',
#    'screen_name': 'nicolsmukaaya',
#    'location': 'kampala uganda',
#    'description': 'The best programming language is the one you know how to use.\nI love Ruby',
#    'url': 'https://t.co/8iD6bxAX7O',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/8iD6bxAX7O',
#        'expanded_url': 'http://www.watts247.com',
#        'display_url': 'watts247.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 23,
#    'friends_count': 249,
#    'listed_count': 0,
#    'created_at': 'Sat Apr 06 15:38:45 +0000 2013',
#    'favourites_count': 87,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 135,
#    'lang': None,
#    'status': {'created_at': 'Thu Aug 06 12:08:50 +0000 2020',
#     'id': 1291345485765251076,
#     'id_str': '1291345485765251076',
#     'text': '@AndrewMwenda By a mere fact that you have posted about people power for a 35th month in a row shows how big this t… https://t.co/VnwYI1Ypor',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'AndrewMwenda',
#        'name': 'Andrew M. Mwenda',
#        'id': 96941094,
#        'id_str': '96941094',
#        'indices': [0, 13]}],
#      'urls': [{'url': 'https://t.co/VnwYI1Ypor',
#        'expanded_url': 'https://twitter.com/i/web/status/1291345485765251076',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': 1291339223828660225,
#     'in_reply_to_status_id_str': '1291339223828660225',
#     'in_reply_to_user_id': 96941094,
#     'in_reply_to_user_id_str': '96941094',
#     'in_reply_to_screen_name': 'AndrewMwenda',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '0099B9',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1280943836550832132/IvXx-uRc_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1280943836550832132/IvXx-uRc_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1331884183/1594313206',
#    'profile_link_color': '0099B9',
#    'profile_sidebar_border_color': '5ED4DC',
#    'profile_sidebar_fill_color': '95E8EC',
#    'profile_text_color': '3C3940',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 722284146,
#    'id_str': '722284146',
#    'name': 'Dilhan 🧚\u200d♀️',
#    'screen_name': 'dilhanaslamaci',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': True,
#    'followers_count': 104,
#    'friends_count': 79,
#    'listed_count': 0,
#    'created_at': 'Sat Jul 28 14:31:59 +0000 2012',
#    'favourites_count': 5349,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 60,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '1A1B1F',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1225099909847748608/Da2eUbbH_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1225099909847748608/Da2eUbbH_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/722284146/1499164071',
#    'profile_link_color': '2FC2EF',
#    'profile_sidebar_border_color': '181A1E',
#    'profile_sidebar_fill_color': '252429',
#    'profile_text_color': '666666',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1201939871033626625,
#    'id_str': '1201939871033626625',
#    'name': 'jasmyne',
#    'screen_name': 'JCreationsss',
#    'location': 'New York, NY',
#    'description': 'UX researcher/designer👩🏽\u200d💻                        Art enthusiast 🎨',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1,
#    'friends_count': 14,
#    'listed_count': 0,
#    'created_at': 'Tue Dec 03 19:02:57 +0000 2019',
#    'favourites_count': 7,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 0,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1291254314925785089/qDAXxYrn_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1291254314925785089/qDAXxYrn_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1201939871033626625/1596693977',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 178644915,
#    'id_str': '178644915',
#    'name': 'Manjeet Jindal',
#    'screen_name': 'manjeetjindal',
#    'location': 'India',
#    'description': '',
#    'url': 'http://t.co/7tSr9eLN2X',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/7tSr9eLN2X',
#        'expanded_url': 'http://manjeetblog.wordpress.com',
#        'display_url': 'manjeetblog.wordpress.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 90,
#    'friends_count': 482,
#    'listed_count': 0,
#    'created_at': 'Sun Aug 15 08:41:56 +0000 2010',
#    'favourites_count': 292,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 1116,
#    'lang': None,
#    'status': {'created_at': 'Mon Aug 03 08:52:59 +0000 2020',
#     'id': 1290209035694641155,
#     'id_str': '1290209035694641155',
#     'text': '@GooglePay  @GooglePayIndia hey google, want to stop frauds? Take note and act\n\n http://159.65.64.149/pp/gpay.php?g… https://t.co/wDNpJfHj9C',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'GooglePay',
#        'name': 'Google Pay',
#        'id': 309827046,
#        'id_str': '309827046',
#        'indices': [0, 10]},
#       {'screen_name': 'GooglePayIndia',
#        'name': 'Google Pay India',
#        'id': 831657713226522624,
#        'id_str': '831657713226522624',
#        'indices': [12, 27]}],
#      'urls': [{'url': 'https://t.co/wDNpJfHj9C',
#        'expanded_url': 'https://twitter.com/i/web/status/1290209035694641155',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': 309827046,
#     'in_reply_to_user_id_str': '309827046',
#     'in_reply_to_screen_name': 'GooglePay',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1386625175/fb_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1386625175/fb_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1092118250555695104,
#    'id_str': '1092118250555695104',
#    'name': 'paolost3',
#    'screen_name': 'Paolo__Stewart',
#    'location': 'London, England',
#    'description': 'Just a man, doing his best to move on from Artax drowning in The Swamp of Sadness.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 4,
#    'friends_count': 294,
#    'listed_count': 0,
#    'created_at': 'Sun Feb 03 17:50:56 +0000 2019',
#    'favourites_count': 439,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 130,
#    'lang': None,
#    'status': {'created_at': 'Thu Jul 30 03:53:42 +0000 2020',
#     'id': 1288684167639830528,
#     'id_str': '1288684167639830528',
#     'text': '@mehdirhasan Or.... Biden is literally THAT bad of candidate?',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'mehdirhasan',
#        'name': 'Mehdi Hasan',
#        'id': 130557513,
#        'id_str': '130557513',
#        'indices': [0, 12]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': 1288679580019183617,
#     'in_reply_to_status_id_str': '1288679580019183617',
#     'in_reply_to_user_id': 130557513,
#     'in_reply_to_user_id_str': '130557513',
#     'in_reply_to_screen_name': 'mehdirhasan',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1192336284217462785/wF9_RBuO_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1192336284217462785/wF9_RBuO_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1092118250555695104/1573110244',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 238575255,
#    'id_str': '238575255',
#    'name': 'Nathan',
#    'screen_name': 'nathorsfall',
#    'location': 'Freiburg, Germany',
#    'description': '',
#    'url': 'https://t.co/0VRYHki3Va',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/0VRYHki3Va',
#        'expanded_url': 'http://horsfallnathan.com',
#        'display_url': 'horsfallnathan.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 214,
#    'friends_count': 474,
#    'listed_count': 2,
#    'created_at': 'Sat Jan 15 14:03:32 +0000 2011',
#    'favourites_count': 523,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 2068,
#    'lang': None,
#    'status': {'created_at': 'Wed Aug 05 09:35:26 +0000 2020',
#     'id': 1290944492103782401,
#     'id_str': '1290944492103782401',
#     'text': '🔥 🔥 https://t.co/FKrpFrFUT5',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/FKrpFrFUT5',
#        'expanded_url': 'https://twitter.com/artbyadesua/status/1290332118447513600',
#        'display_url': 'twitter.com/artbyadesua/st…',
#        'indices': [4, 27]}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1290332118447513600,
#     'quoted_status_id_str': '1290332118447513600',
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'und'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1032413652899442690/L_SJOv2l_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1032413652899442690/L_SJOv2l_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/238575255/1487394619',
#    'profile_link_color': '9266CC',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1291225500191461377,
#    'id_str': '1291225500191461377',
#    'name': 'Ruby Allshouse',
#    'screen_name': 'allshouse_ruby',
#    'location': '',
#    'description': 'Pop culture maven. Zombie junkie. Passionate web guru. Explorer. Incurable bacon evangelist. Analyst. Food fan. Student.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 0,
#    'friends_count': 10,
#    'listed_count': 0,
#    'created_at': 'Thu Aug 06 04:12:09 +0000 2020',
#    'favourites_count': 0,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 0,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1291225772137512960/LqWE9ZRb_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1291225772137512960/LqWE9ZRb_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 76572422,
#    'id_str': '76572422',
#    'name': 'vinoth',
#    'screen_name': 'vinothrao',
#    'location': 'Coimbatore, India',
#    'description': 'Diving deep into azure',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 77,
#    'friends_count': 415,
#    'listed_count': 1,
#    'created_at': 'Wed Sep 23 05:56:51 +0000 2009',
#    'favourites_count': 3483,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 360,
#    'lang': None,
#    'status': {'created_at': 'Thu Aug 06 04:12:54 +0000 2020',
#     'id': 1291225713970880512,
#     'id_str': '1291225713970880512',
#     'text': "@marcelCruz Good one.I thought the common hooks are usestate and useeffect. It's even in the list.",
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'marcelCruz',
#        'name': 'Marcel Cruz',
#        'id': 2959072858,
#        'id_str': '2959072858',
#        'indices': [0, 11]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': 1290885779485491200,
#     'in_reply_to_status_id_str': '1290885779485491200',
#     'in_reply_to_user_id': 2959072858,
#     'in_reply_to_user_id_str': '2959072858',
#     'in_reply_to_screen_name': 'marcelCruz',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/987661748176998400/vZbdQqoE_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/987661748176998400/vZbdQqoE_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 28317168,
#    'id_str': '28317168',
#    'name': 'Salah Abdeldayem',
#    'screen_name': 'salahabdeldayem',
#    'location': 'Cairo, Egypt',
#    'description': '❤️ Coffee, FMCG expert, Loves eCommerce and new pioneer ideas',
#    'url': 'https://t.co/hndtrilzdX',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/hndtrilzdX',
#        'expanded_url': 'http://www.abdeldayem.com',
#        'display_url': 'abdeldayem.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 463,
#    'friends_count': 3487,
#    'listed_count': 8,
#    'created_at': 'Thu Apr 02 10:59:33 +0000 2009',
#    'favourites_count': 827,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 1489,
#    'lang': None,
#    'status': {'created_at': 'Thu Aug 06 14:40:10 +0000 2020',
#     'id': 1291383570280439808,
#     'id_str': '1291383570280439808',
#     'text': '@DivineOps please accept my condolences may Allah rest her soul 🙏',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'DivineOps',
#        'name': 'Sasha Rosenbaum',
#        'id': 444131405,
#        'id_str': '444131405',
#        'indices': [0, 10]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': 1291378316889460736,
#     'in_reply_to_status_id_str': '1291378316889460736',
#     'in_reply_to_user_id': 444131405,
#     'in_reply_to_user_id_str': '444131405',
#     'in_reply_to_screen_name': 'DivineOps',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '0099B9',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/576860153992998912/-6XcpDlR_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/576860153992998912/-6XcpDlR_normal.jpeg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/28317168/1426369212',
#    'profile_link_color': '0099B9',
#    'profile_sidebar_border_color': '5ED4DC',
#    'profile_sidebar_fill_color': '95E8EC',
#    'profile_text_color': '3C3940',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'}],
#  'next_cursor': 1674240847311423049,
#  'next_cursor_str': '1674240847311423049',
#  'previous_cursor': 0,
#  'previous_cursor_str': '0',
#  'total_count': None}

# %% [markdown]
# ## Section 4: Functions

# %% [markdown]
# This section details the functions you have to write and turn in as part of your homework assignment.
#
# Please read the requirements carefully.
#
# **What you'll turn in:** A `.py` file with all of the functions written.  We should be able to load this into an IDE, run the file, and then call your functions to verify how and if they work. This file should also be properly commented so we can follow your line of reasoning.
#
# The functions you'll be prompted to write will be defined in the following ways:
#
#  - **name:** the name of the function
#  - **returns:** what the function should return
#  - **arguments:** arguments to include inside the function in order to specify how it should behave.
#
#  **Note:** The free API has limitations built into it, so this means from time-to-time you'll only be able to return some of the results from the API.  This is fine.  It's understood and recognized that your functions won't be able to return an entire list of someone's users or other such things, so as long as your work delivers the best it can under present circumstances you'll be in good shape.
#
#  **Other Note:** Every aspect of the API that you need to use can be found on either of these pages.
#
#  Search API:  https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets
#
#  Users API: https://developer.twitter.com/en/docs/accounts-and-users/follow-search-get-users/api-reference
#
# **Remarks About Your Final Work**
#
#  - It's okay if you get stuck somewhere.  If there's one item that you can't figure out and it doesn't quite work right, it's probably best to move on and try other things.  Again, try and explain what you were looking to do.  You'll pass if you give an honest effort.
#  - There's potentially a lot of error handling you could do to verify user input is correct, but you can leave that alone for now.  Just make sure the core purpose of the function works the way it's supposed to.
#  - While you're working on this, it's possible you may bump into your API limits.  Keep this in mind if you have a function that's working, but 45 minutes later it doesn't and you haven't changed anything.  This usually means the data you're getting back from your API calls isn't what it's supposed to be because you've exhausted your limits. We won't hold you to double checking for all of this in your functions.
#  - In the file you turn in, make sure your requests are referencing your API tokens, so that way we can run your file right away.  Ie, make sure somewhere in your script you have a variable at the top that reads `tokens = OAuth1('token1', 'token2', 'token3', 'token4')` so it can be used for your requests inside the file.

# %% [markdown]
# ##### Function 1 (Required)

# %% [markdown]
# **Name:** `find_user`
#
# **Returns:** dictionary that represents user object returned by Twitter's API
#
# **Arguments:**
#  - `screen_name`: str, required; Twitter handle to search for.  **Can include the @ symbol.  The function should check for this and remove it if necessary.**
#  - `keys`: list, optional; list that contains keys to return about user object.  If not specified, then function should return the entire user object.  **These only need to be outer keys.** If they are keys nested within another key, you don't have to account for this.
#
# **To test:** We'll test your function in the following ways:
#
#  - `find_user('@GA')`
#  - `find_user('GA')`
#  - `find_user('GA', keys=['name', 'screen_name', 'followers_count', 'friends_count'])`

# %%
import requests
from requests_oauthlib import OAuth1

base_url = 'https://api.twitter.com/1.1/account/verify_credentials.json'
# search = '?q='

user_base_url = 'https://api.twitter.com/1.1/users/lookup.json'
user_search = '?screen_name='

auth = OAuth1('yRFD3WsOMN80LbeY3ugWxpduM', 'cuxQuVFpfFhIBcwNN9KPk3Qz3bOxH48ZRJJNFOTD91jeiyfX6W', '1288869541515350017-57MZSQRwrCSQ3XcZsbwKe1pGWg0Vcq', '8qnWLDyFTnn7oyUJ7Xo8NvuGKFRoM8waoLeg9bRKI3zso')

def find_user(user, keys=None):
    
    results = requests.get(user_base_url + user_search + user.replace('@',''), auth=auth).json()[0]

    if keys != None:
        reduced_results = {}
        for key in keys:
            reduced_results[key] = results[key]
        return reduced_results
    
    else:
        return results

# find_user('@GA', keys=['name', 'screen_name', 'followers_count', 'friends_count'])
find_user('@GA')
# Out:
# {'id': 170393291,
#  'id_str': '170393291',
#  'name': 'General Assembly',
#  'screen_name': 'GA',
#  'location': '',
#  'description': 'We transform careers and teams — including more than one third of the Fortune 100 — through dynamic courses in coding, data, design, and business.',
#  'url': 'https://t.co/YQeEXPxJ4H',
#  'entities': {'url': {'urls': [{'url': 'https://t.co/YQeEXPxJ4H',
#      'expanded_url': 'http://ga.co/Twitter',
#      'display_url': 'ga.co/Twitter',
#      'indices': [0, 23]}]},
#   'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 165517,
#  'friends_count': 5416,
#  'listed_count': 3263,
#  'created_at': 'Sat Jul 24 18:19:59 +0000 2010',
#  'favourites_count': 36405,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': True,
#  'verified': True,
#  'statuses_count': 22756,
#  'lang': None,
#  'status': {'created_at': 'Sat Aug 08 17:27:02 +0000 2020',
#   'id': 1292150339995607045,
#   'id_str': '1292150339995607045',
#   'text': '5 benefits of coding that can be useful in other aspects of your life:\n✅ Problem solving\n✅ Attention to detail\n✅ La… https://t.co/6ydISO2O1M',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/6ydISO2O1M',
#      'expanded_url': 'https://twitter.com/i/web/status/1292150339995607045',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 4,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': 'FFFFFF',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': True,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1267818300416745472/A3qO4Fer_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1267818300416745472/A3qO4Fer_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/170393291/1480618900',
#  'profile_link_color': 'DE2233',
#  'profile_sidebar_border_color': 'FFFFFF',
#  'profile_sidebar_fill_color': 'FFFFFF',
#  'profile_text_color': '000000',
#  'profile_use_background_image': True,
#  'has_extended_profile': False,
#  'default_profile': False,
#  'default_profile_image': False,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none'}

# %% [markdown]
# ##### Function 2 (Required)

# %% [markdown]
# **Name:** `find_hashtag`
#
# **Returns:** list of data objects that contain information about each tweet that matches the hashtag provided as input.
#
# **Arguments:**
#  - `hashtag`: str, required; text to use as a hashtag search.
#  - `count`: int, optional; number of results to return
#  - `search_type`: str, optional; type of results to return.  should accept 3 different values:
#    - `mixed`:   return mix of most recent and most popular results
#    - `recent`:  return most recent results
#    - `popular`: return most popular results
#
# **Note:** User should **not** have to actually use the `#` character for the `hashtag` argument.  The function should check to see if it's there, and if not, add it in for them.
#
# **To Test:**  We'll check your function in the following ways:
#  - `find_hashtag('DataScience')`
#  - `find_hashtag('#DataScience')`
#  - `find_hashtag('#DataScience', count=100)`, and double check the length of the `statuses` key to make sure it contains the right amount of results.  **Note:** Due to the version of the API we're using, the number of results returned will **not** necessarily match the value passed into the `count` parameter.  So if you specify 50 and it only returns 45, you are likely still doing it correctly.
#  - `find_hashtag('#DataScience', search_type='recent/mixed/popular')`

# %%
import requests
from requests_oauthlib import OAuth1

base_url = 'https://api.twitter.com/1.1/search/tweets.json'
tweets = '?qtext='
count = '&count='
result_type = '&result_type='

auth = OAuth1('yRFD3WsOMN80LbeY3ugWxpduM', 'cuxQuVFpfFhIBcwNN9KPk3Qz3bOxH48ZRJJNFOTD91jeiyfX6W', '1288869541515350017-57MZSQRwrCSQ3XcZsbwKe1pGWg0Vcq', '8qnWLDyFTnn7oyUJ7Xo8NvuGKFRoM8waoLeg9bRKI3zso')

def find_hashtag(hashtag, keys=None):
    search_results = requests.get(base_url + tweets + count + search_type + tweets.replace('#',''), auth=auth).json()

    if keys != None:
        reduced_results = {}
        for key in keys:
            reduced_results[key] = {}
            reduced_results = [key for key in keys]
            return reduced_results
        else:
            return search_results

find_hashtag('DataScience',  keys=['tweets', 'count', 'result_type'])
# Out:
# ['tweets', 'count', 'result_type']

# %% [markdown]
# ##### Function 3 (Required)

# %% [markdown]
# **Name:** `get_followers`
#
# **Returns:** list of data objects for each of the users followers, returning values for the `name`, `followers_count`, `friends_count`, and `screen_name` key for each user.
#
# **Arguments:**
#
#  - `screen_name`: str, required; Twitter handle to search for.  **Results should not depend on user inputting the @ symbol.**
#  - `keys`: list, required;  keys to return for each user.  default value: [`name`, `followers_count`, `friends_count`, `screen_name`]; if something else is listed, values for those keys should be returned
#  - `to_df`: bool, required; default value: False; if True, return results in a dataframe.  Every value provided in the `keys` argument should be its own column, with rows populated by the corresponding values for each one for every user.
#
# **To Test:** We'll test your functions in the following ways:
#
#  - `get_followers('@GA')`
#  - `get_followers('GA')`
#  - `get_followers('GA', keys=['name', 'followers_count'])`
#  - `get_followers('GA', keys=['name', 'followers_count'], to_df=True)`
#  - `get_followers('GA', to_df=True)`

# %%
#function find_user: finds user specified in argument, can provide keys for additional information

import requests
from requests_oauthlib import OAuth1

import pandas as pd

base_url = 'https://api.twitter.com/1.1/account/verify_credentials.json'

user_base_url = 'https://api.twitter.com/1.1/users/lookup.json'
user_search = '?screen_name='

auth = OAuth1('yRFD3WsOMN80LbeY3ugWxpduM', 'cuxQuVFpfFhIBcwNN9KPk3Qz3bOxH48ZRJJNFOTD91jeiyfX6W', '1288869541515350017-57MZSQRwrCSQ3XcZsbwKe1pGWg0Vcq', '8qnWLDyFTnn7oyUJ7Xo8NvuGKFRoM8waoLeg9bRKI3zso')

def get_followers (screen_name, keys=None, to_df=False):
    
    results = requests.get(user_base_url + user_search + screen_name.replace('@',''), auth=auth).json()[0]
    
    if keys != None:
        reduced_results = {}
        for key in keys:
            reduced_results[key] = results[key]
        if to_df==True:
            df = pd.DataFrame(reduced_results,index=[0]) #setting index as 0 as pandas is enforcing an index
            return df
        else:
            return reduced_results
    
    else:
        if to_df==True:
            df = pd.DataFrame(results,index=[0]) #setting index as 0 as pandas is enforcing an index
            return df
        else:
            return results

get_followers('@GA', keys=['name', 'screen_name', 'followers_count', 'friends_count'], to_df=True)
# get_followers('@GA')
# get_followers('GA')
# get_followers('GA', keys=['name', 'followers_count'])
# get_followers('GA', keys=['name', 'followers_count'], to_df=True)
# get_followers('GA', to_df=True)
# Out:
#                name screen_name  followers_count  friends_count
# 0  General Assembly          GA           165515           5416

# %% [markdown]
# ##### Function 4 (Optional)

# %% [markdown]
# **Name:** `friends_of_friends`
#
# **Returns:** list of data objects for each user that two Twitter users have in common
#
# **Arguments:**
#
#  - `names`: list, required; list of two Twitter users to compare friends list with
#  - `keys`: list, optional; list of keys to return for information about each user.  Default value should be to return the entire data object.
#  - `to_df`: bool, required; default value: False; if True, returns results in a dataframe.
#
# **To Test:** We'll test your function in the following ways:
#
#  - `friends_of_friends(['Beyonce', 'MariahCarey'])`
#  - `friends_of_friends(['@Beyonce', '@MariahCarey'], to_df=True)`
#  - `friends_of_friends(['Beyonce', 'MariahCarey'], keys=['id', 'name'])`
#  - `friends_of_friends(['Beyonce', 'MariahCarey'], keys=['id', 'name'], to_df=True)`
#
# Each of these should return 3 results. (Assuming they haven't followed the same people since this was last written).
#
# **Hint:** The `id` key is the unique identifier for someone, so if you want to check if two people are the same this is the best way to do it.

# %% [markdown]
#  ##### Function 5 (Optional)

# %% [markdown]
# Rewrite the `friends_of_friends` function, except this time include an argument called `full_search`, which accepts a boolean value.  If set to `True`, use cursoring to cycle through the complete set of users for the users provided.
#
# The twitter API only returns a subset of users in your results to save bandwidth, so you have to cycle through multiple result sets to get all of the values.
#
# You can read more about how this works here:  https://developer.twitter.com/en/docs/basics/cursoring
#
# Basically you have to do a `while` loop to continually make a new request using the values stored in the `next_cursor` key as part of your next query string until there's nothing left to search.
#
# **Note:** We're using the free API, so we're operating under some limitations.  One of them being that you can only make 15 API calls in a 15 minute span to this portion of the API.  You can also only return up to 200 results per cursor, so this means you won't be able to completely search for everyone even if you set this up correctly.
#
# That's fine, just do what you can under the circumstances.
#
# **To Test:** To test your function, we'll run the following function calls:
#
#  - `friends_of_friends(['ezraklein', 'tylercowen'])` -- should return 4 results if you do an API call that returns 200 results
#  - `friends_of_friends(['ezraklein', 'tylercowen'], full_search=True)` -- should return 54 results if you do an API call that returns 200 results
#
# **Hint:** Chances are you will exhaust your API limits quite easily in this function depending on who you search for.  Depending on how you have things set up, this could cause error messages to arise when things are otherwise fine.  Remember in class 3 when we were getting those weird dictionaries back because our limits were used up?  We won't hold you accountable for handling this inside your function, although it could make some things easier for your own testing.
#
# Good luck!
